# %% [markdown]
# # Deploy and monitor a machine learning workflow for Image Classification

# %% [markdown]
# ## Setting up this notebook
#
# Notes about the instance size and kernel setup: this notebook has been tested on
#
# 1. The `Python 3 (Data Science)` kernel
# 2. The `ml.t3.medium` instance
#
# ## Data Staging
#
# We'll use a sample dataset called CIFAR to simulate the challenges Scones Unlimited are facing in Image Classification. In order to start working with CIFAR we'll need to:
#
# 1. Extract the data from a hosting service
# 2. Transform it into a usable shape and format
# 3. Load it into a production system
#
# In other words, we're going to do some simple ETL!
#
# ### 1. Extract the data from the hosting service
#
# In the cell below, define a function `extract_cifar_data` that extracts python version of the CIFAR-100 dataset. The CIFAR dataaset is open source and generously hosted by the University of Toronto at: https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz

# %%
# !tar chvfz ./project.tar.gz *
# Out:
# cifar-100-python/
# cifar-100-python/test
# cifar-100-python/file.txt~
# cifar-100-python/train
# cifar-100-python/meta
# cifar.tar.gz
# file.png
# project.tar.gz
# tar: project.tar.gz: file changed as we read it
# starter.ipynb
# test/
# test/discharge_lamp_s_000988.png
# test/school_bus_s_002243.png
# test/flounder_s_002137.png
# test/feather_palm_s_000112.png
# test/panthera_leo_s_001144.png
# test/dozer_s_000044.png
# test/alp_s_001941.png
# test/leopard_s_000023.png
# test/infant_s_001623.png
# test/harvest_mouse_s_001051.png
# test/male_child_s_000820.png
# test/sweater_girl_s_001003.png
# test/tractor_s_000670.png
# test/adriatic_s_000902.png
# test/nematode_s_000915.png
# test/tractor_s_001723.png
# test/trout_s_002633.png
# test/telephone_set_s_001471.png
# test/dinosaur_s_002032.png
# test/pine_tree_s_001493.png
# test/squirrel_s_001004.png
# test/young_lady_s_000647.png
# test/cichlid_s_001524.png
# test/cirrocumulus_s_000078.png
# test/caterpillar_s_001026.png
# test/beaver_s_000340.png
# test/shark_s_001909.png
# test/chimpanzee_s_000987.png
# test/butterfly_s_000326.png
# test/army_tank_s_000051.png
# test/acer_saccharum_s_001505.png
# test/macoun_s_000441.png
# test/cricetus_cricetus_s_000531.png
# test/kangaroo_s_002879.png
# test/railroad_train_s_001079.png
# test/porbeagle_s_000281.png
# test/skunk_s_000682.png
# test/tiger_beetle_s_000566.png
# test/chimpanzee_s_000035.png
# test/butterfly_orchid_s_001020.png
# test/arabian_camel_s_000049.png
# test/dozer_s_000602.png
# test/bartlett_s_000802.png
# test/sofa_s_000559.png
# test/anjou_s_000645.png
# test/armoured_combat_vehicle_s_000018.png
# test/breakfast_table_s_000882.png
# test/caterpillar_s_000450.png
# test/oriental_cockroach_s_000954.png
# test/keyboard_s_000092.png
# test/bigarade_s_000076.png
# test/ankylosaurus_s_000731.png
# test/stegosaurus_s_001600.png
# test/bear_s_001647.png
# test/goldfish_s_001902.png
# test/bear_s_000918.png
# test/mcintosh_s_000142.png
# test/boy_s_001755.png
# test/honeybee_s_000607.png
# test/dessert_plate_s_000238.png
# test/tin_can_s_001186.png
# test/armoured_combat_vehicle_s_000810.png
# test/ladybug_s_001379.png
# test/skyscraper_s_000023.png
# test/adam_s_000243.png
# test/whale_s_002144.png
# test/forest_s_001125.png
# test/soda_bottle_s_000039.png
# test/castor_fiber_s_000603.png
# test/kangaroo_s_000064.png
# test/telephone_set_s_000427.png
# test/bear_s_001010.png
# test/eared_seal_s_000025.png
# test/gecko_s_000946.png
# test/valencia_orange_s_000590.png
# test/planaria_s_000668.png
# test/seal_s_000412.png
# test/cirrocumulus_s_000195.png
# test/castor_canadensis_s_001599.png
# test/rorqual_s_000015.png
# test/crab_s_001496.png
# test/streetcar_s_000663.png
# test/butterfly_s_000281.png
# test/macoun_s_000009.png
# test/clock_s_001753.png
# test/pickup_truck_s_000017.png
# test/telephone_set_s_001039.png
# test/discharge_lamp_s_001521.png
# test/golden_hamster_s_000277.png
# test/streetcar_s_000582.png
# test/mount_s_000450.png
# test/lobster_s_000010.png
# test/ballistic_missile_s_001528.png
# test/argiope_aurantia_s_000296.png
# test/beer_can_s_000337.png
# test/sweet_pepper_s_002151.png
# test/indian_elephant_s_000126.png
# test/leopard_s_001031.png
# test/telephone_s_001968.png
# test/clavier_s_000213.png
# test/leopard_s_000858.png
# test/bosc_s_000122.png
# test/saucer_s_000045.png
# test/shumard_oak_s_000086.png
# test/cockroach_s_000645.png
# test/snail_s_001398.png
# test/lobster_s_000566.png
# test/lion_cub_s_000001.png
# test/maul_oak_s_000012.png
# test/cattle_s_000366.png
# test/sea_trout_s_000204.png
# test/honeybee_s_001615.png
# test/right_whale_s_001085.png
# test/goblet_s_001347.png
# test/pine_s_001744.png
# test/porcupine_s_000896.png
# test/television_s_001414.png
# test/baby_s_000347.png
# test/otter_s_000941.png
# test/trout_s_002273.png
# test/dozer_s_000008.png
# test/clock_s_000628.png
# test/adam_s_001332.png
# test/tulip_s_002219.png
# test/arabian_camel_s_000166.png
# test/oak_tree_s_001674.png
# test/alarm_clock_s_001120.png
# test/wardrobe_s_001311.png
# test/golden_willow_s_000204.png
# test/bartlett_pear_s_000595.png
# test/cockroach_s_001059.png
# test/sunflower_s_000124.png
# test/gecko_s_001990.png
# test/poppy_s_000677.png
# test/camel_s_002062.png
# test/gray_wolf_s_002196.png
# test/hedgehog_s_000100.png
# test/girl_s_000266.png
# test/cichlid_s_001245.png
# test/sorex_araneus_s_000292.png
# test/scarlet_oak_s_000004.png
# test/pine_tree_s_001916.png
# test/footbridge_s_000403.png
# test/beetle_s_000812.png
# test/easy_chair_s_001199.png
# test/great_grey_kangaroo_s_000011.png
# test/sea_s_001558.png
# test/tin_can_s_001762.png
# test/indian_elephant_s_000027.png
# test/turbot_s_001047.png
# test/streetcar_s_002265.png
# test/tiger_s_000719.png
# test/castor_fiber_s_000306.png
# test/cain_s_000818.png
# test/castor_fiber_s_001035.png
# test/silver_maple_s_000117.png
# test/golden_delicious_s_000210.png
# test/closet_s_000963.png
# test/poppy_s_000893.png
# test/school_bus_s_001613.png
# test/bulldozer_s_001897.png
# test/mountain_rose_s_001053.png
# test/red_fox_s_000401.png
# test/carphophis_amoenus_s_000004.png
# test/squirrel_s_001578.png
# test/whiskey_bottle_s_000168.png
# test/garden_snail_s_000966.png
# test/river_otter_s_000223.png
# test/orchid_s_000210.png
# test/panthera_leo_s_001243.png
# test/common_dolphin_s_000868.png
# test/infant_s_001722.png
# test/crocodile_s_000701.png
# test/telephone_s_000503.png
# test/plaice_s_000770.png
# test/cup_s_001874.png
# test/tree_squirrel_s_000006.png
# test/castle_s_001519.png
# test/pan_troglodytes_s_000068.png
# test/chalice_s_001585.png
# test/mus_musculus_s_000061.png
# test/lion_s_001216.png
# test/goblet_s_000276.png
# test/intercontinental_ballistic_missile_s_000538.png
# test/palm_tree_s_000289.png
# test/fin_whale_s_001158.png
# test/hedgehog_s_001286.png
# test/cain_s_000179.png
# test/stegosaur_s_000069.png
# test/ballistic_missile_s_000772.png
# test/rainbow_trout_s_000166.png
# test/numbfish_s_000088.png
# test/africanized_bee_s_000467.png
# test/halibut_s_000577.png
# test/lobster_s_001592.png
# test/cattle_s_000186.png
# test/beer_bottle_s_001965.png
# test/butterfly_orchid_s_000865.png
# test/camel_s_000181.png
# test/saucer_s_001071.png
# test/wardrobe_s_001687.png
# test/lizard_s_001786.png
# test/male_child_s_000442.png
# test/halibut_s_000102.png
# test/seal_s_001994.png
# test/chimp_s_001899.png
# test/shark_s_000003.png
# test/armoured_combat_vehicle_s_000117.png
# test/snake_s_000046.png
# test/golden_hamster_s_000736.png
# test/school_bus_s_001136.png
# test/canis_lupus_s_000114.png
# test/beer_can_s_000553.png
# test/antiballistic_missile_s_000004.png
# test/snail_s_000050.png
# test/snail_s_000768.png
# test/cichlid_s_000930.png
# test/beer_bottle_s_002102.png
# test/leopard_s_000957.png
# test/elephant_s_002144.png
# test/argiope_aurantia_s_000001.png
# test/macoun_s_000027.png
# test/right_whale_s_000059.png
# test/syrian_hamster_s_001477.png
# test/acer_saccharinum_s_000103.png
# test/schistosome_s_000209.png
# test/seal_s_001240.png
# test/tiger_s_002294.png
# test/train_s_001661.png
# test/elephant_s_000281.png
# test/lawn_mower_s_000791.png
# test/porcupine_s_000205.png
# test/forest_s_001107.png
# test/acer_saccharinum_s_000659.png
# test/beaker_s_000099.png
# test/dessert_plate_s_000058.png
# test/shrew_s_001585.png
# test/kangaroo_s_000046.png
# test/dozer_s_000503.png
# test/bachelor_girl_s_000708.png
# test/dolphin_s_002318.png
# test/power_mower_s_000321.png
# test/bulldozer_s_001701.png
# test/cloud_s_000669.png
# test/macropus_giganteus_s_000075.png
# test/possum_s_000131.png
# test/morchella_esculenta_s_000675.png
# test/tank_s_001148.png
# test/fishbowl_s_002507.png
# test/pickup_s_002194.png
# test/panthera_leo_s_000316.png
# test/baby_s_002147.png
# test/trout_s_002615.png
# test/missile_s_001401.png
# test/mus_musculus_s_001312.png
# test/poppy_s_000220.png
# test/twin_towers_s_001060.png
# test/world_trade_center_s_000588.png
# test/porcupine_s_000520.png
# test/infant_s_000633.png
# test/reclining_chair_s_001055.png
# test/panthera_tigris_s_000611.png
# test/quercus_petraea_s_000694.png
# test/eames_chair_s_000443.png
# test/bunk_s_000138.png
# test/sweet_pepper_s_001125.png
# test/lapin_s_001502.png
# test/chimpanzee_s_000170.png
# test/panthera_pardus_s_000191.png
# test/silver_maple_s_001521.png
# test/oxen_s_001755.png
# test/gray_wolf_s_001647.png
# test/lapin_s_001896.png
# test/bed_s_001448.png
# test/honeybee_s_001714.png
# test/gecko_s_001297.png
# test/lamp_s_000783.png
# test/opossum_s_001894.png
# test/plain_s_001151.png
# test/worm_s_000007.png
# test/lobster_s_000980.png
# test/sunflower_s_000887.png
# test/arabian_camel_s_000373.png
# test/turkey_oak_s_000428.png
# test/navel_orange_s_000641.png
# test/clock_s_000835.png
# test/colubrid_s_000305.png
# test/armoured_combat_vehicle_s_000342.png
# test/dessert_plate_s_000481.png
# test/palm_s_001197.png
# test/sugar_maple_s_000048.png
# test/bungalow_s_000445.png
# test/table_s_001111.png
# test/skyscraper_s_002210.png
# test/mount_s_003015.png
# test/castor_canadensis_s_001016.png
# test/elephant_s_000317.png
# test/tulip_s_000482.png
# test/bulldozer_s_001251.png
# test/castor_fiber_s_000135.png
# test/elephant_s_002810.png
# test/butterfly_orchid_s_001189.png
# test/dwarf_tulip_s_000029.png
# test/caterpillar_s_000225.png
# test/bus_s_000099.png
# test/pickup_truck_s_000620.png
# test/nullarbor_plain_s_000053.png
# test/tiger_beetle_s_000971.png
# test/red_delicious_s_001772.png
# test/panthera_leo_s_001234.png
# test/sunflower_s_000250.png
# test/armored_dinosaur_s_000248.png
# test/kangaroo_s_001603.png
# test/adriatic_s_000911.png
# test/built_in_bed_s_001227.png
# test/pickup_truck_s_002240.png
# test/dual_carriageway_s_000062.png
# test/turtle_s_000138.png
# test/bulldozer_s_002061.png
# test/soda_bottle_s_001092.png
# test/pear_s_000758.png
# test/couch_s_002260.png
# test/bottle_s_001458.png
# test/bee_s_001627.png
# test/king_of_beasts_s_000149.png
# test/durmast_s_000129.png
# test/drawbridge_s_000917.png
# test/crocodile_s_000134.png
# test/turtle_s_002073.png
# test/sorex_araneus_s_000346.png
# test/shrew_s_001693.png
# test/lamp_s_000495.png
# test/closet_s_000477.png
# test/bear_s_001818.png
# test/tiger_s_001835.png
# test/hedgehog_s_001439.png
# test/dungeness_crab_s_002016.png
# test/mcintosh_s_000151.png
# test/hamster_s_000789.png
# test/milk_can_s_001319.png
# test/opossum_s_000321.png
# test/nematode_s_001095.png
# test/wolf_pup_s_000853.png
# test/willow_tree_s_000645.png
# test/bear_cub_s_002043.png
# test/cichlid_fish_s_001567.png
# test/alarm_clock_s_000758.png
# test/computer_keyboard_s_001813.png
# test/pickup_truck_s_000699.png
# test/sea_turtle_s_001210.png
# test/telephone_set_s_000274.png
# test/infant_s_001236.png
# test/lapin_s_000798.png
# test/tiger_beetle_s_000656.png
# test/skunk_s_000772.png
# test/school_bus_s_000236.png
# test/adam_s_002034.png
# test/spider_s_003020.png
# test/cichlid_s_002109.png
# test/serengeti_plain_s_000199.png
# test/bed_s_000188.png
# test/byway_s_001933.png
# test/butterfly_s_000731.png
# test/dasyatis_centroura_s_000044.png
# test/gecko_s_000199.png
# test/honeybee_s_001507.png
# test/panthera_tigris_s_000323.png
# test/shark_s_001279.png
# test/golden_hamster_s_001456.png
# test/pinon_pine_s_001228.png
# test/rose_s_001828.png
# test/hedgehog_s_000467.png
# test/pickup_s_000169.png
# test/rabbit_s_000888.png
# test/otter_s_000716.png
# test/whiskey_bottle_s_000438.png
# test/seal_s_000421.png
# test/leopard_s_000948.png
# test/pinon_s_000332.png
# test/lobster_s_000656.png
# test/seal_s_002203.png
# test/goblet_s_000780.png
# test/house_s_001106.png
# test/cichlid_s_000048.png
# test/rainbow_trout_s_001561.png
# test/railroad_train_s_001367.png
# test/camel_s_000055.png
# test/clock_s_000952.png
# test/wardrobe_s_000589.png
# test/lobster_s_002195.png
# test/easy_chair_s_000578.png
# test/sheet_iron_s_000246.png
# test/sugar_maple_s_000165.png
# test/roundworm_s_000474.png
# test/hognose_snake_s_001223.png
# test/squirrel_s_002102.png
# test/butterfly_s_002153.png
# test/trout_s_000185.png
# test/lady_tulip_s_000104.png
# test/rose_s_002197.png
# test/armoured_combat_vehicle_s_000621.png
# test/train_s_000761.png
# test/yellowtail_flounder_s_000242.png
# test/golden_delicious_s_001765.png
# test/dessert_plate_s_000049.png
# test/hognose_snake_s_000170.png
# test/crocodile_s_003005.png
# test/girl_s_001409.png
# test/sunflower_s_000214.png
# test/computer_keyboard_s_001057.png
# test/common_dolphin_s_000499.png
# test/chimpanzee_s_000080.png
# test/pickup_s_001294.png
# test/seal_s_000106.png
# test/bulldozer_s_000243.png
# test/mushroom_s_001296.png
# test/mushroom_s_000567.png
# test/shark_s_002287.png
# test/byway_s_001177.png
# test/train_s_001418.png
# test/pickup_s_001456.png
# test/quercus_rubra_s_001512.png
# test/cichlid_s_000363.png
# test/chimpanzee_s_001214.png
# test/dessert_plate_s_000283.png
# test/guitarfish_s_000024.png
# test/lapin_s_001331.png
# test/wallaby_s_000196.png
# test/butterfly_s_000056.png
# test/anjou_s_001662.png
# test/snake_s_000073.png
# test/red_fox_s_000669.png
# test/infant_s_000381.png
# test/common_dolphin_s_000024.png
# test/red_fox_s_002111.png
# test/chimp_s_001037.png
# test/river_otter_s_000151.png
# test/tulipa_clusiana_s_000077.png
# test/spider_s_001497.png
# test/snake_s_000451.png
# test/pickup_s_001915.png
# test/sugar_maple_s_000066.png
# test/coffee_can_s_000012.png
# test/beetle_s_000821.png
# test/trout_s_000086.png
# test/lawn_mower_s_000683.png
# test/forest_s_001710.png
# test/armored_combat_vehicle_s_000257.png
# test/skyscraper_s_001893.png
# test/mushroom_s_001593.png
# test/skunk_s_001528.png
# test/panthera_leo_s_001252.png
# test/lizard_s_001399.png
# test/didelphis_virginiana_s_000834.png
# test/sofa_s_000982.png
# test/baby_s_000572.png
# test/roach_s_000834.png
# test/panthera_tigris_s_000107.png
# test/lamp_s_001962.png
# test/alp_s_000447.png
# test/salt_flat_s_000198.png
# test/icbm_s_001484.png
# test/sea_turtle_s_000659.png
# test/squirrel_s_000696.png
# test/breakfast_table_s_000756.png
# test/fur_seal_s_000038.png
# test/butterfly_s_001082.png
# test/mount_s_002779.png
# test/streetcar_s_000735.png
# test/drawbridge_s_001664.png
# test/alarm_clock_s_000695.png
# test/bed_s_002780.png
# test/butterfly_s_000830.png
# test/school_bus_s_000173.png
# test/soda_can_s_000767.png
# test/pine_tree_s_000395.png
# test/mushroom_s_001278.png
# test/railroad_train_s_001745.png
# test/infant_s_000282.png
# test/parkway_s_000319.png
# test/dessert_plate_s_000265.png
# test/tapeworm_s_000580.png
# test/raccoon_s_001895.png
# test/willow_tree_s_002364.png
# test/snail_s_000500.png
# test/rose_s_001684.png
# test/cockroach_s_000870.png
# test/tiger_beetle_s_000674.png
# test/red_fox_s_000489.png
# test/date_palm_s_000005.png
# test/beaver_s_000052.png
# test/opossum_s_002202.png
# test/tractor_s_001273.png
# test/grey_wolf_s_001814.png
# test/volcano_s_000028.png
# test/woman_s_000118.png
# test/wardrobe_s_000411.png
# test/squirrel_s_001866.png
# test/ankylosaurus_s_001613.png
# test/lounge_chair_s_000327.png
# test/intercontinental_ballistic_missile_s_000187.png
# test/raccoon_s_002113.png
# test/keyboard_s_002027.png
# test/closet_s_001188.png
# test/baby_s_001904.png
# test/leopard_s_001301.png
# test/ring_road_s_000322.png
# test/forest_s_000144.png
# test/cloud_s_000041.png
# test/dolphin_s_002246.png
# test/lutra_canadensis_s_000264.png
# test/crab_s_000400.png
# test/bee_s_000718.png
# test/right_whale_s_000860.png
# test/crab_s_000794.png
# test/black_woman_s_000752.png
# test/caterpillar_s_001969.png
# test/bear_s_002286.png
# test/sunflower_s_002410.png
# test/porcupine_s_001499.png
# test/dungeness_crab_s_000135.png
# test/cockroach_s_000834.png
# test/shark_s_001099.png
# test/lutra_canadensis_s_000345.png
# test/stingray_s_002135.png
# test/hamster_s_000134.png
# test/sorex_araneus_s_000247.png
# test/sugar_maple_s_000345.png
# test/white_woman_s_000361.png
# test/stingray_s_001082.png
# test/snail_s_002478.png
# test/dessert_plate_s_000067.png
# test/macropus_giganteus_s_000408.png
# test/willow_s_000059.png
# test/gecko_s_000658.png
# test/field_s_000026.png
# test/mako_shark_s_001119.png
# test/goblet_s_001374.png
# test/soda_bottle_s_000183.png
# test/cichlid_s_001353.png
# test/spider_s_002982.png
# test/verpa_bohemica_s_000223.png
# test/bell_pepper_s_001100.png
# test/railroad_train_s_001781.png
# test/train_s_000383.png
# test/oriental_cockroach_s_001359.png
# test/macropus_giganteus_s_000246.png
# test/arabian_camel_s_000274.png
# test/sea_turtle_s_000299.png
# test/rabbit_s_000035.png
# test/clock_s_002194.png
# test/orchid_s_000021.png
# test/pickup_s_001474.png
# test/lift_bridge_s_000179.png
# test/computer_keyboard_s_000184.png
# test/tv_s_001476.png
# test/camel_s_000550.png
# test/panthera_leo_s_000325.png
# test/forest_s_000621.png
# test/sea_turtle_s_001982.png
# test/rosebush_s_001682.png
# test/common_dolphin_s_000598.png
# test/oxen_s_002493.png
# test/poppy_s_002486.png
# test/goldfish_s_001335.png
# test/rose_s_001882.png
# test/bear_cub_s_000009.png
# test/longfin_mako_s_000062.png
# test/pine_tree_s_002294.png
# test/footbridge_s_000052.png
# test/armchair_s_000265.png
# test/boy_s_000712.png
# test/orchid_s_001721.png
# test/american_lobster_s_000433.png
# test/couch_s_000954.png
# test/coffee_can_s_000542.png
# test/willow_tree_s_000241.png
# test/butterfly_s_000964.png
# test/true_pine_s_000009.png
# test/adriatic_s_001558.png
# test/pop_bottle_s_001263.png
# test/bartlett_pear_s_000083.png
# test/cows_s_002132.png
# test/panthera_pardus_s_000379.png
# test/bos_taurus_s_000049.png
# test/cup_s_001227.png
# test/beer_bottle_s_001633.png
# test/argiope_aurantia_s_000423.png
# test/rose_s_001424.png
# test/wardrobe_s_002165.png
# test/motor_mower_s_000460.png
# test/breakfast_table_s_000019.png
# test/delphinus_delphis_s_000736.png
# test/field_mouse_s_000107.png
# test/opossum_s_000392.png
# test/dwarf_tulip_s_000102.png
# test/leopard_s_000661.png
# test/plaice_s_000598.png
# test/fur_seal_s_000568.png
# test/date_palm_s_000139.png
# test/baby_s_001993.png
# test/hedgehog_s_000225.png
# test/bear_s_001889.png
# test/tree_squirrel_s_000545.png
# test/chalice_s_001253.png
# test/tiger_s_001512.png
# test/bowl_s_001753.png
# test/sunflower_s_000960.png
# test/mus_musculus_s_000447.png
# test/spider_s_002605.png
# test/missile_s_000536.png
# test/toddy_palm_s_000106.png
# test/chimp_s_001963.png
# test/television_system_s_001643.png
# test/boardinghouse_s_000712.png
# test/pear_s_001083.png
# test/rabbit_s_001096.png
# test/little_girl_s_000018.png
# test/beer_bottle_s_000508.png
# test/hamster_s_001834.png
# test/raccoon_s_002841.png
# test/clock_s_000512.png
# test/mushroom_s_002143.png
# test/arabian_camel_s_000050.png
# test/bear_cub_s_000098.png
# test/seal_s_001185.png
# test/otter_s_000033.png
# test/sounding_rocket_s_000051.png
# test/bus_s_000019.png
# test/hognose_snake_s_000286.png
# test/bottle_s_000721.png
# test/crocodylus_niloticus_s_000031.png
# test/oak_tree_s_000037.png
# test/mushroom_s_001333.png
# test/haze_s_000741.png
# test/possum_s_002173.png
# test/wood_s_001235.png
# test/bungalow_s_000041.png
# test/clock_s_002213.png
# test/television_s_001854.png
# test/lemon_sole_s_000034.png
# test/shark_s_000380.png
# test/couch_s_000558.png
# test/red_willow_s_000192.png
# test/sea_s_002036.png
# test/beaker_s_000604.png
# test/gecko_s_001082.png
# test/poppy_s_000804.png
# test/ink_bottle_s_000054.png
# test/boat_train_s_000782.png
# test/adam_s_001691.png
# test/mushroom_s_000442.png
# test/delphinus_delphis_s_000259.png
# test/bear_s_000127.png
# test/lawn_mower_s_000306.png
# test/fur_seal_s_000685.png
# test/verpa_s_001311.png
# test/shark_s_000425.png
# test/carassius_auratus_s_000200.png
# test/spider_s_000067.png
# test/trout_s_002758.png
# test/sofa_s_000524.png
# test/quercus_rubra_s_000692.png
# test/adriatic_sea_s_000173.png
# test/infant_s_001111.png
# test/boardinghouse_s_001243.png
# test/pickup_s_000161.png
# test/navel_orange_s_000201.png
# test/common_dolphin_s_001067.png
# test/pine_s_001430.png
# test/trolleybus_s_000096.png
# test/crab_s_001902.png
# test/chalice_s_000722.png
# test/forest_s_001484.png
# test/halibut_s_000605.png
# test/lapin_s_000916.png
# test/colubrid_s_000259.png
# test/bungalow_s_000005.png
# test/silver_maple_s_001664.png
# test/motorway_s_000486.png
# test/cup_s_000453.png
# test/honeybee_s_001301.png
# test/nematode_worm_s_000003.png
# test/trolleybus_s_000258.png
# test/adriatic_s_001675.png
# test/lion_s_000585.png
# test/bell_pepper_s_000262.png
# test/dessert_plate_s_000203.png
# test/lapin_s_002536.png
# test/sea_trout_s_000284.png
# test/mouse_s_000119.png
# test/chimp_s_001846.png
# test/pickup_s_000242.png
# test/skyscraper_s_001435.png
# test/oxen_s_000613.png
# test/bosc_s_001174.png
# test/sofa_s_000047.png
# test/nematode_s_000007.png
# test/poppy_s_000921.png
# test/breakfast_table_s_000370.png
# test/streetcar_s_001796.png
# test/mackerel_shark_s_001034.png
# test/butterfly_s_001738.png
# test/clock_s_000710.png
# test/butterfly_s_003196.png
# test/highway_s_001101.png
# test/mako_s_001119.png
# test/intercontinental_ballistic_missile_s_000008.png
# test/poppy_s_002703.png
# test/pachycephalosaurus_s_001069.png
# test/oriental_roach_s_000208.png
# test/streetcar_s_000511.png
# test/eagle_ray_s_000065.png
# test/dozer_s_001375.png
# test/wolf_s_001317.png
# test/areca_s_000503.png
# test/maine_lobster_s_000817.png
# test/grey_wolf_s_000141.png
# test/train_s_003030.png
# test/lift_bridge_s_000315.png
# test/panthera_tigris_s_000439.png
# test/chaise_s_000502.png
# test/elephant_s_002368.png
# test/sunflower_s_002382.png
# test/snail_s_001165.png
# test/house_s_001258.png
# test/wood_s_001989.png
# test/stingray_s_002188.png
# test/lapin_s_002770.png
# test/kangaroo_s_002925.png
# test/altar_boy_s_001240.png
# test/colubrid_s_000655.png
# test/red_fox_s_001714.png
# test/tulipa_clusiana_s_000015.png
# test/rose_s_001145.png
# test/army_tank_s_001544.png
# test/bowl_s_002365.png
# test/boy_s_001243.png
# test/mushroom_s_002260.png
# test/volcano_s_000200.png
# test/television_s_002781.png
# test/lift_bridge_s_001125.png
# test/tulip_s_001885.png
# test/shark_s_000029.png
# test/pearmain_s_000142.png
# test/squirrel_s_000553.png
# test/bus_s_000136.png
# test/leopard_s_000382.png
# test/mourning_cloak_s_001227.png
# test/sunflower_s_000348.png
# test/mount_s_000197.png
# test/mountain_s_000360.png
# test/quercus_robur_s_001729.png
# test/bed_s_000045.png
# test/pickup_truck_s_000394.png
# test/beaver_s_000285.png
# test/table_s_002019.png
# test/telephone_s_001159.png
# test/lamp_s_001324.png
# test/caterpillar_s_001682.png
# test/acer_saccharinum_s_001272.png
# test/numbfish_s_000017.png
# test/possum_s_000256.png
# test/navel_orange_s_000496.png
# test/sofa_s_000344.png
# test/saucer_s_001394.png
# test/tree_squirrel_s_000806.png
# test/boy_s_001621.png
# test/divided_highway_s_000416.png
# test/dessert_plate_s_000104.png
# test/mount_s_002852.png
# test/opossum_s_000491.png
# test/ladybeetle_s_000072.png
# test/purple_osier_s_000038.png
# test/rose_s_000713.png
# test/brown_bear_s_000003.png
# test/woods_s_000170.png
# test/young_girl_s_000399.png
# test/camelus_dromedarius_s_000327.png
# test/bear_s_002080.png
# test/caterpillar_s_001763.png
# test/sofa_s_000425.png
# test/possum_s_000337.png
# test/field_s_002554.png
# test/tulipa_clusiana_s_000150.png
# test/raccoon_s_001491.png
# test/opossum_s_001625.png
# test/bottle_s_002206.png
# test/breakfast_table_s_000910.png
# test/squirrel_s_001903.png
# test/oilcan_s_000437.png
# test/tiger_s_001530.png
# test/nemertean_s_000230.png
# test/world_trade_center_s_001282.png
# test/streetcar_s_001778.png
# test/manual-beaver005.png
# test/man_s_000800.png
# test/oxen_s_002530.png
# test/adriatic_sea_s_001280.png
# test/banded_gecko_s_000086.png
# test/tangerine_s_000106.png
# test/mushroom_s_000703.png
# test/garden_snail_s_001624.png
# test/keyboard_s_000991.png
# test/sunflower_s_002364.png
# test/feather_palm_s_000534.png
# test/breakfast_table_s_000190.png
# test/apis_mellifera_s_000599.png
# test/bartlett_pear_s_000029.png
# test/train_s_001867.png
# test/crocodylus_porosus_s_000649.png
# test/chimpanzee_s_000691.png
# test/balmoral_castle_s_000771.png
# test/woman_s_000110.png
# test/garden_snail_s_001543.png
# test/byway_s_000897.png
# test/nullarbor_plain_s_001357.png
# test/ankylosaurus_s_000120.png
# test/lapin_s_000097.png
# test/lift_bridge_s_000054.png
# test/crab_s_001407.png
# test/caterpillar_s_000557.png
# test/bee_s_001007.png
# test/seville_orange_s_000023.png
# test/palm_tree_s_000416.png
# test/rainbow_trout_s_001578.png
# test/striped_skunk_s_001058.png
# test/swamp_white_oak_s_000002.png
# test/sea_turtle_s_000057.png
# test/mushroom_s_000343.png
# test/sweet_pepper_s_000638.png
# test/cattle_s_001042.png
# test/colubrid_s_000358.png
# test/cloud_s_000670.png
# test/forest_s_001826.png
# test/mount_s_001367.png
# test/bulldozer_s_001385.png
# test/shark_s_001253.png
# test/access_road_s_001516.png
# test/colubrid_s_000277.png
# test/orange_s_001151.png
# test/computer_keyboard_s_000023.png
# test/poppy_s_000462.png
# test/tussock_caterpillar_s_000060.png
# test/raccoon_s_002580.png
# test/bowl_s_000367.png
# test/dessert_plate_s_000221.png
# test/adriatic_sea_s_000272.png
# test/skunk_s_001959.png
# test/bear_cub_s_000638.png
# test/access_road_s_000067.png
# test/shumard_oak_s_000033.png
# test/tractor_s_000104.png
# test/honeybee_s_000032.png
# test/cortland_s_000454.png
# test/bear_cub_s_001367.png
# test/bell_pepper_s_000046.png
# test/wardrobe_s_001094.png
# test/tulipa_clusiana_s_000114.png
# test/breakfast_table_s_000550.png
# test/stegosaurus_s_000771.png
# test/butterfly_s_000865.png
# test/crab_s_000633.png
# test/sorex_araneus_s_000005.png
# test/mako_shark_s_001111.png
# test/bulldozer_s_000098.png
# test/sea_s_001604.png
# test/cichlid_fish_s_000335.png
# test/beaver_s_001932.png
# test/computer_keyboard_s_001310.png
# test/otter_s_000330.png
# test/marine_turtle_s_000090.png
# test/navel_orange_s_000298.png
# test/train_s_002956.png
# test/golden_hamster_s_000062.png
# test/carphophis_amoenus_s_000282.png
# test/pine_s_000242.png
# test/bartlett_pear_s_000227.png
# test/otter_s_001221.png
# test/field_mouse_s_000008.png
# test/bus_s_000154.png
# test/lobster_s_001879.png
# test/coluber_constrictor_s_000348.png
# test/rabbit_s_000691.png
# test/rorqual_s_000707.png
# test/crab_s_000741.png
# test/bear_s_000532.png
# test/cup_s_002127.png
# test/wardrobe_s_001364.png
# test/male_child_s_001566.png
# test/tree_squirrel_s_000635.png
# test/hognose_snake_s_001663.png
# test/appian_way_s_000146.png
# test/tulipa_clusiana_s_000060.png
# test/train_s_000015.png
# test/raccoon_s_001644.png
# test/caterpillar_s_001754.png
# test/telephone_set_s_000759.png
# test/helix_pomatia_s_000277.png
# test/boy_s_002260.png
# test/forest_s_000010.png
# test/raccoon_s_000591.png
# test/clock_s_000206.png
# test/tussock_caterpillar_s_000015.png
# test/step_rocket_s_000386.png
# test/bowl_s_001762.png
# test/sour_orange_s_000934.png
# test/cloud_s_000463.png
# test/poppy_s_001146.png
# test/didelphis_virginiana_s_000106.png
# test/wolf_pup_s_001430.png
# test/alarm_clock_s_000363.png
# test/syrian_hamster_s_001433.png
# test/oriental_cockroach_s_000253.png
# test/sunflower_s_002193.png
# test/soda_bottle_s_001739.png
# test/tv_s_001423.png
# test/train_s_000330.png
# test/table_s_002406.png
# test/black_woman_s_001113.png
# test/whale_s_000298.png
# test/baby_s_000321.png
# test/castor_canadensis_s_000367.png
# test/morchella_esculenta_s_001522.png
# test/tiger_s_000072.png
# test/couch_s_002268.png
# test/bed_s_001323.png
# test/grey_wolf_s_000114.png
# test/chaise_s_000151.png
# test/tank_s_000051.png
# test/red_fox_s_000391.png
# test/surveillance_system_s_000775.png
# test/power_mower_s_001166.png
# test/butterfly_orchid_s_001037.png
# test/lady_tulip_s_000229.png
# test/cloud_s_001750.png
# test/castor_fiber_s_000296.png
# test/discharge_lamp_s_000926.png
# test/butterfly_orchid_s_000227.png
# test/missile_s_000068.png
# test/wood_s_001244.png
# test/man_s_001995.png
# test/pear_s_001173.png
# test/sunflower_s_001707.png
# test/tiger_s_000153.png
# test/red_fox_s_001525.png
# test/corduroy_s_000328.png
# test/butterfly_s_003088.png
# test/train_s_002031.png
# test/sunflower_s_001383.png
# test/girl_s_000402.png
# test/infant_s_000947.png
# test/raccoon_s_000870.png
# test/right_whale_s_000132.png
# test/sister_s_000334.png
# test/kangaroo_s_002457.png
# test/step_rocket_s_000827.png
# test/drawbridge_s_000720.png
# test/female_child_s_000205.png
# test/dungeness_crab_s_000917.png
# test/world_trade_center_s_001237.png
# test/mount_s_002168.png
# test/snail_s_001813.png
# test/stegosaurus_s_000366.png
# test/pickup_s_000888.png
# test/helix_pomatia_s_000718.png
# test/possum_s_001174.png
# test/bowl_s_002770.png
# test/skyscraper_s_000553.png
# test/infant_s_001757.png
# test/chimp_s_000964.png
# test/television_system_s_000644.png
# test/female_child_s_001015.png
# test/red_fox_s_000274.png
# test/breakfast_table_s_001117.png
# test/bachelor_girl_s_000700.png
# test/rosebush_s_001987.png
# test/squirrel_s_001930.png
# test/edible_snail_s_000072.png
# test/nematode_s_000250.png
# test/porcupine_s_000753.png
# test/world_trade_center_s_000904.png
# test/chimpanzee_s_000961.png
# test/beer_can_s_000113.png
# test/mackerel_shark_s_001043.png
# test/phone_s_002161.png
# test/mushroom_s_001621.png
# test/whale_s_001387.png
# test/nile_crocodile_s_000432.png
# test/skunk_s_001232.png
# test/manual-beaver032.png
# test/minibus_s_000085.png
# test/break_seal_s_000263.png
# test/little_girl_s_000225.png
# test/apis_mellifera_s_000313.png
# test/dozer_s_000655.png
# test/american_lobster_s_000244.png
# test/mus_musculus_s_000339.png
# test/television_s_001188.png
# test/sunflower_s_000852.png
# test/power_mower_s_000716.png
# test/field_s_000646.png
# test/stone_crab_s_000488.png
# test/lutra_canadensis_s_000013.png
# test/leopard_s_001606.png
# test/railroad_train_s_000405.png
# test/gecko_s_000722.png
# test/alarm_clock_s_000084.png
# test/television_s_002790.png
# test/common_dolphin_s_000905.png
# test/camel_s_000459.png
# test/soda_can_s_000318.png
# test/soda_can_s_001047.png
# test/poppy_s_001902.png
# test/poppy_s_002631.png
# test/maple_s_000966.png
# test/red_delicious_s_002214.png
# test/cichlid_s_000031.png
# test/bowl_s_000097.png
# test/trout_s_001140.png
# test/lounge_chair_s_000130.png
# test/bartlett_pear_s_000272.png
# test/coffee_can_s_001622.png
# test/acer_saccharum_s_001459.png
# test/wardrobe_s_001382.png
# test/garden_snail_s_000346.png
# test/clock_s_000305.png
# test/orchid_s_000146.png
# test/bartlett_pear_s_000434.png
# test/willow_tree_s_002212.png
# test/phone_s_000127.png
# test/minibus_s_000544.png
# test/cloud_s_000724.png
# test/forest_s_000827.png
# test/butterfly_s_002935.png
# test/sweet_pepper_s_001970.png
# test/telephone_s_001960.png
# test/tv_s_000073.png
# test/river_otter_s_000078.png
# test/lift_bridge_s_000540.png
# test/brown_bear_s_000012.png
# test/panthera_pardus_s_000649.png
# test/sunflower_s_000438.png
# test/bowl_s_002671.png
# test/step_rocket_s_000566.png
# test/elephant_s_001864.png
# test/crab_s_001731.png
# test/rabbit_s_001681.png
# test/common_opossum_s_000006.png
# test/forest_s_001637.png
# test/lamp_s_001252.png
# test/bus_s_000442.png
# test/eve_s_000004.png
# test/river_otter_s_001446.png
# test/castor_canadensis_s_000709.png
# test/tiger_beetle_s_000045.png
# test/bed_s_001897.png
# test/shark_s_002270.png
# test/bowl_s_000493.png
# test/caterpillar_s_001376.png
# test/sweet_pepper_s_000845.png
# test/leopard_s_000454.png
# test/sofa_s_000038.png
# test/palm_tree_s_002081.png
# test/chaise_s_001222.png
# test/slip_road_s_000241.png
# test/aegean_s_000757.png
# test/breakfast_table_s_000523.png
# test/tv_s_000550.png
# test/butterfly_s_001567.png
# test/common_iguana_s_000214.png
# test/bear_s_001126.png
# test/rose_s_000407.png
# test/red_fox_s_001381.png
# test/clock_s_002240.png
# test/wine_palm_s_000305.png
# test/rushlight_s_000226.png
# test/forest_s_001871.png
# test/sunflower_s_002292.png
# test/field_mouse_s_000530.png
# test/raccoon_s_001347.png
# test/water_shrew_s_000162.png
# test/built_in_bed_s_000596.png
# test/highway_s_000838.png
# test/timber_wolf_s_000145.png
# test/valencia_orange_s_001401.png
# test/closet_s_000901.png
# test/cichlid_s_001793.png
# test/reclining_chair_s_000937.png
# test/otter_s_000859.png
# test/flounder_s_000867.png
# test/bear_cub_s_001259.png
# test/mako_shark_s_000112.png
# test/wolf_pup_s_000080.png
# test/private_road_s_000299.png
# test/streetcar_s_000698.png
# test/eating_apple_s_000920.png
# test/sunflower_s_001446.png
# test/acer_saccharinum_s_000912.png
# test/lapin_s_001915.png
# test/woman_s_000002.png
# test/beaver_s_001383.png
# test/leopard_s_001147.png
# test/bartlett_pear_s_000632.png
# test/mount_s_000728.png
# test/tulip_s_001759.png
# test/table_s_001173.png
# test/gecko_s_000263.png
# test/lizard_s_000950.png
# test/oriental_cockroach_s_000073.png
# test/power_mower_s_000419.png
# test/raccoon_s_002832.png
# test/valencia_orange_s_000231.png
# test/shark_s_000290.png
# test/armchair_s_000733.png
# test/worm_snake_s_001265.png
# test/bartlett_s_001449.png
# test/golden_willow_s_000716.png
# test/sofa_s_000470.png
# test/poppy_s_001362.png
# test/twin_towers_s_000744.png
# test/discharge_lamp_s_000584.png
# test/breakfast_table_s_001135.png
# test/desk_phone_s_000596.png
# test/sunflower_s_002418.png
# test/pickup_truck_s_000682.png
# test/bell_pepper_s_001342.png
# test/computer_keyboard_s_001479.png
# test/rorqual_s_000680.png
# test/arabian_camel_s_000122.png
# test/sunflower_s_001365.png
# test/apis_mellifera_s_000016.png
# test/red_delicious_s_000711.png
# test/butterfly_s_002494.png
# test/rose_s_000362.png
# test/american_lobster_s_000181.png
# test/pine_s_000332.png
# test/dozer_s_001564.png
# test/cirrocumulus_s_000070.png
# test/tv_s_000037.png
# test/castor_fiber_s_000917.png
# test/icbm_s_000009.png
# test/soda_can_s_000093.png
# test/nematode_s_000034.png
# test/syrian_hamster_s_001091.png
# test/tin_can_s_001106.png
# test/serengeti_s_000905.png
# test/bed_s_002430.png
# test/stegosaurus_s_000069.png
# test/couch_s_001917.png
# test/chalice_s_001163.png
# test/streetcar_s_001510.png
# test/helminth_s_000326.png
# test/cirrocumulus_s_001598.png
# test/pachycephalosaur_s_000008.png
# test/wardrobe_s_000455.png
# test/flounder_s_001794.png
# test/mus_musculus_s_001086.png
# test/telephone_set_s_000104.png
# test/adriatic_s_001549.png
# test/willow_tree_s_001123.png
# test/crocodile_s_001168.png
# test/coluber_constrictor_flaviventris_s_000003.png
# test/beaver_s_000096.png
# test/feather_palm_s_000822.png
# test/bus_s_000325.png
# test/soda_can_s_000174.png
# test/tram_s_000475.png
# test/racoon_s_000020.png
# test/television_s_002259.png
# test/lobster_s_001888.png
# test/butterfly_s_002737.png
# test/bowhead_s_000109.png
# test/red_fox_s_000139.png
# test/guitarfish_s_000761.png
# test/tulipa_clusiana_s_000204.png
# test/colubrid_s_000844.png
# test/beer_can_s_000050.png
# test/humpback_s_000306.png
# test/bee_s_002105.png
# test/seal_s_000924.png
# test/navel_orange_s_000469.png
# test/date_palm_s_000922.png
# test/squirrel_s_002362.png
# test/chimpanzee_s_002055.png
# test/skyscraper_s_000180.png
# test/soda_can_s_001151.png
# test/plaice_s_001485.png
# test/forest_s_001606.png
# test/rosebush_s_000885.png
# test/butterfly_s_000168.png
# test/mourning_cloak_s_000071.png
# test/cancer_magister_s_000216.png
# test/seal_s_000137.png
# test/minibus_s_001323.png
# test/rainbow_trout_s_000386.png
# test/kangaroo_s_001274.png
# test/boarding_house_s_001141.png
# test/forest_s_001282.png
# test/wardrobe_s_002242.png
# test/tulip_s_000639.png
# test/lawn_mower_s_000498.png
# test/butterfly_s_000087.png
# test/streetcar_s_001198.png
# test/beaver_s_001154.png
# test/ladybeetle_s_000050.png
# test/power_mower_s_000028.png
# test/porcupine_s_001514.png
# test/butterfly_orchid_s_001895.png
# test/field_mouse_s_000022.png
# test/poppy_s_000879.png
# test/bungalow_s_000278.png
# test/rorqual_s_000370.png
# test/sunflower_s_000326.png
# test/bed_s_002199.png
# test/pickup_truck_s_000138.png
# test/sea_s_001141.png
# test/bear_cub_s_000337.png
# test/butterfly_s_002184.png
# test/eating_apple_s_001024.png
# test/banded_gecko_s_001036.png
# test/nematode_s_001882.png
# test/crab_s_000170.png
# test/red_fox_s_001350.png
# test/lobster_s_001497.png
# test/hognose_snake_s_000363.png
# test/bulldozer_s_002290.png
# test/streetcar_s_001675.png
# test/pear_s_001241.png
# test/dessert_apple_s_000221.png
# test/forest_s_000157.png
# test/rose_s_000133.png
# test/male_child_s_000347.png
# test/crab_s_001304.png
# test/gecko_s_000986.png
# test/armored_combat_vehicle_s_000468.png
# test/poppy_s_000008.png
# test/coachwhip_s_000118.png
# test/beer_bottle_s_002124.png
# test/bus_s_000015.png
# test/breakfast_table_s_000886.png
# test/seal_s_001899.png
# test/bear_s_001489.png
# test/kangaroo_s_002642.png
# test/anjou_s_000649.png
# test/baby_s_002808.png
# test/castle_s_002549.png
# test/quercus_lobata_s_000312.png
# test/dwarf_tulip_s_000096.png
# test/forest_s_001048.png
# test/kangaroo_s_002480.png
# test/carphophis_amoenus_s_000143.png
# test/oriental_roach_s_000006.png
# test/squirrel_s_002052.png
# test/navel_orange_s_000159.png
# test/field_s_000192.png
# test/girl_s_001593.png
# test/field_s_003027.png
# test/seal_s_001343.png
# test/spider_s_001314.png
# test/fox_s_000595.png
# test/rabbit_s_001092.png
# test/brown_snail_s_000495.png
# test/table_s_001061.png
# test/chimpanzee_s_002091.png
# test/tank_s_000639.png
# test/forest_s_000751.png
# test/garden_snail_s_001161.png
# test/male_child_s_000941.png
# test/pedunculate_oak_s_000246.png
# test/crocodile_s_002505.png
# test/turtle_s_000169.png
# test/nematode_s_001846.png
# test/squirrel_s_001044.png
# test/pickup_s_000794.png
# test/poppy_s_000440.png
# test/alarm_clock_s_000710.png
# test/sugar_maple_s_001924.png
# test/ornithischian_s_000319.png
# test/byway_s_001012.png
# test/indian_elephant_s_000841.png
# test/garden_snail_s_000513.png
# test/tree_squirrel_s_000820.png
# test/skyscraper_s_002403.png
# test/beaver_s_001514.png
# test/boarding_house_s_001420.png
# test/icbm_s_000849.png
# test/leopard_s_000225.png
# test/rainbow_trout_s_001000.png
# test/discharge_lamp_s_001363.png
# test/butterfly_s_001176.png
# test/orchid_s_000869.png
# test/intercontinental_ballistic_missile_s_000875.png
# test/slip_road_s_000012.png
# test/sunflower_s_001415.png
# test/highway_s_001095.png
# test/bed_s_001112.png
# test/butterfly_s_000609.png
# test/streetcar_s_001002.png
# test/striped_skunk_s_000145.png
# test/adriatic_sea_s_001060.png
# test/caterpillar_s_002191.png
# test/bunk_s_000673.png
# test/balmoral_castle_s_000074.png
# test/pickup_s_000479.png
# test/american_lobster_s_000231.png
# test/right_whale_s_000279.png
# test/built_in_bed_s_001654.png
# test/bowl_s_001632.png
# test/cloud_s_000333.png
# test/common_dolphin_s_000730.png
# test/lutra_canadensis_s_000556.png
# test/couch_s_001643.png
# test/woods_s_000031.png
# test/adriatic_s_002085.png
# test/disciotis_venosa_s_000055.png
# test/male_child_s_000383.png
# test/cloud_s_000090.png
# test/chimpanzee_s_000075.png
# test/raccoon_s_000380.png
# test/panthera_tigris_s_000435.png
# test/lioness_s_000003.png
# test/bell_pepper_s_000024.png
# test/red_delicious_s_002298.png
# test/possum_s_001008.png
# test/ribbon_worm_s_000466.png
# test/leopard_s_001512.png
# test/stingray_s_001374.png
# test/television_s_001418.png
# test/tram_s_000363.png
# test/television_system_s_000235.png
# test/dessert_plate_s_000359.png
# test/chimp_s_000555.png
# test/rosebush_s_000687.png
# test/willow_tree_s_001783.png
# test/bowl_s_001218.png
# test/golden_delicious_s_000689.png
# test/twin_towers_s_000371.png
# test/cirrocumulus_s_001864.png
# test/tree_squirrel_s_000721.png
# test/army_tank_s_000073.png
# test/mushroom_s_000778.png
# test/otter_s_001179.png
# test/worm_s_000128.png
# test/adam_s_002362.png
# test/lawn_mower_s_000203.png
# test/butterfly_s_001239.png
# test/oriental_cockroach_s_000499.png
# test/tiger_s_000399.png
# test/kangaroo_s_000806.png
# test/golden_willow_s_001153.png
# test/television_s_000824.png
# test/roble_s_000327.png
# test/fieldmouse_s_000003.png
# test/bell_pepper_s_001212.png
# test/house_s_000903.png
# test/mus_musculus_s_000380.png
# test/mako_shark_s_001069.png
# test/seal_s_000236.png
# test/streetcar_s_000649.png
# test/poppy_s_001232.png
# test/ascaris_lumbricoides_s_000342.png
# test/palm_tree_s_001105.png
# test/cichlid_s_001465.png
# test/eames_chair_s_000483.png
# test/cows_s_001973.png
# test/sunflower_s_002126.png
# test/hognose_snake_s_000066.png
# test/striped_skunk_s_000127.png
# test/stone_crab_s_000691.png
# test/boarding_house_s_001958.png
# test/bowl_s_000408.png
# test/common_dolphin_s_000235.png
# test/black_woman_s_000387.png
# test/winter_flounder_s_000315.png
# test/wood_s_000520.png
# test/sea_s_000430.png
# test/panthera_tigris_s_000336.png
# test/racoon_s_000365.png
# test/serengeti_s_001898.png
# test/lift_bridge_s_001659.png
# test/bed_s_001965.png
# test/mus_musculus_s_000308.png
# test/common_dolphin_s_000550.png
# test/flatfish_s_000465.png
# test/little_girl_s_000669.png
# test/man_s_000004.png
# test/raccoon_s_002225.png
# test/world_trade_center_s_002250.png
# test/american_lobster_s_000051.png
# test/keyboard_s_000357.png
# test/streetcar_s_001693.png
# test/acer_saccharinum_s_000143.png
# test/boy_s_001696.png
# test/eagle_ray_s_000043.png
# test/bosc_s_002043.png
# test/leopard_s_001332.png
# test/otter_s_001100.png
# test/baby_s_002664.png
# test/disciotis_venosa_s_000037.png
# test/forest_s_000337.png
# test/coffee_can_s_001688.png
# test/butterfly_orchid_s_001204.png
# test/boy_s_000411.png
# test/wardrobe_s_002107.png
# test/candle_s_000126.png
# test/roundworm_s_000210.png
# test/anjou_s_001558.png
# test/cichlid_s_001906.png
# test/butterfly_s_001437.png
# test/leopard_s_001215.png
# test/serengeti_s_000091.png
# test/panthera_leo_s_000716.png
# test/black_woman_s_001557.png
# test/pine_tree_s_002210.png
# test/forest_s_001822.png
# test/lion_s_000761.png
# test/bowl_s_002145.png
# test/tv_s_002040.png
# test/oriental_cockroach_s_001588.png
# test/chimp_s_000096.png
# test/couch_s_000536.png
# test/bell_pepper_s_000600.png
# test/mount_s_002254.png
# test/nile_crocodile_s_001013.png
# test/inkpot_s_000191.png
# test/oriental_cockroach_s_000778.png
# test/kangaroo_s_000842.png
# test/bos_taurus_s_000423.png
# test/dungeness_crab_s_000049.png
# test/female_child_s_001101.png
# test/tiger_s_000041.png
# test/table_s_002213.png
# test/pine_s_000479.png
# test/lion_s_001571.png
# test/electric_ray_s_000424.png
# test/eared_seal_s_000209.png
# test/gecko_s_000412.png
# test/wing_chair_s_000050.png
# test/baby_s_002466.png
# test/cankerworm_s_000133.png
# test/leopard_s_001134.png
# test/common_dolphin_s_000271.png
# test/clock_s_000488.png
# test/boy_s_002310.png
# test/spider_s_000009.png
# test/woman_s_000149.png
# test/missile_s_002215.png
# test/soda_can_s_000161.png
# test/seal_s_000038.png
# test/lamp_s_001122.png
# test/dolphin_s_001665.png
# test/crab_s_001601.png
# test/rose_s_000430.png
# test/lutra_canadensis_s_000736.png
# test/camel_s_001193.png
# test/clock_s_001379.png
# test/caterpillar_s_000913.png
# test/wolf_s_002141.png
# test/coluber_constrictor_s_000317.png
# test/gecko_s_000016.png
# test/chimpanzee_s_001227.png
# test/telephone_s_000066.png
# test/american_lobster_s_000411.png
# test/couch_s_001661.png
# test/fin_whale_s_001279.png
# test/cirrocumulus_s_000300.png
# test/pine_tree_s_001004.png
# test/northern_lobster_s_000204.png
# test/panthera_pardus_s_000438.png
# test/sea_trout_s_000226.png
# test/argiope_aurantia_s_000957.png
# test/cattle_s_000388.png
# test/honeybee_s_001637.png
# test/power_mower_s_001531.png
# test/dungeness_crab_s_000445.png
# test/rosebush_s_000311.png
# test/lawn_mower_s_000005.png
# test/eagle_ray_s_000241.png
# test/route_s_001385.png
# test/balmoral_castle_s_001064.png
# test/alp_s_002737.png
# test/army_tank_s_000037.png
# test/minibus_s_000414.png
# test/computer_keyboard_s_000890.png
# test/hedgehog_s_000041.png
# test/rose_s_001402.png
# test/male_child_s_001616.png
# test/northern_lobster_s_000042.png
# test/tulip_s_001269.png
# test/willow_tree_s_001747.png
# test/common_dolphin_s_001009.png
# test/golden_hamster_s_000301.png
# test/lamp_s_001759.png
# test/house_s_001191.png
# test/mus_musculus_s_001316.png
# test/poppy_s_002033.png
# test/minibus_s_001170.png
# test/bear_cub_s_000661.png
# test/plate_s_003151.png
# test/forest_s_002182.png
# test/river_otter_s_001820.png
# test/nematode_s_000766.png
# test/ankylosaurus_s_000429.png
# test/gecko_s_000124.png
# test/beetle_s_000726.png
# test/right_whale_s_000567.png
# test/armoured_combat_vehicle_s_000265.png
# test/kangaroo_s_002174.png
# test/kangaroo_s_000716.png
# test/pickup_truck_s_001353.png
# test/bottle_s_000411.png
# test/opossum_s_001612.png
# test/closet_s_001212.png
# test/palm_tree_s_001015.png
# test/pine_tree_s_002003.png
# test/camel_s_000653.png
# test/lapin_s_002424.png
# test/breakfast_table_s_000105.png
# test/world_trade_center_s_000306.png
# test/camel_s_001706.png
# test/cichlid_fish_s_001330.png
# test/didelphis_virginiana_s_000021.png
# test/right_whale_s_000486.png
# test/dolphin_s_002583.png
# test/lawn_mower_s_001398.png
# test/caterpillar_s_000229.png
# test/disciotis_venosa_s_000181.png
# test/hedgehog_s_000311.png
# test/trout_s_002565.png
# test/clavier_s_000262.png
# test/salix_viminalis_s_000022.png
# test/whiskey_bottle_s_000397.png
# test/rainbow_trout_s_000953.png
# test/armoured_combat_vehicle_s_000661.png
# test/sea_turtle_s_000323.png
# test/tulip_s_000963.png
# test/sand_dab_s_000040.png
# test/mower_s_002112.png
# test/power_mower_s_001081.png
# test/valencia_orange_s_000882.png
# test/beer_bottle_s_000270.png
# test/chimp_s_002067.png
# test/research_rocket_s_000183.png
# test/squirrel_s_001969.png
# test/bear_s_000132.png
# test/house_s_001065.png
# test/elephant_s_000636.png
# test/american_lobster_s_000042.png
# test/delphinus_delphis_s_001317.png
# test/stingray_s_002319.png
# test/motor_mower_s_000312.png
# test/leopard_s_002133.png
# test/panthera_tigris_s_000408.png
# test/poppy_s_000017.png
# test/indian_elephant_s_000094.png
# test/bus_s_000024.png
# test/chimp_s_001419.png
# test/africanized_honey_bee_s_000030.png
# test/surveillance_system_s_000771.png
# test/salix_purpurea_s_000057.png
# test/railroad_train_s_001013.png
# test/striped_skunk_s_000514.png
# test/sorex_cinereus_s_000002.png
# test/field_s_001254.png
# test/goldfish_s_000862.png
# test/balaenoptera_physalus_s_000262.png
# test/house_mouse_s_000202.png
# test/possum_s_000360.png
# test/couch_s_002147.png
# test/man_s_001955.png
# test/mower_s_000688.png
# test/rabbit_s_001146.png
# test/lady_tulip_s_000108.png
# test/river_otter_s_000416.png
# test/bulldozer_s_000805.png
# test/table_s_000897.png
# test/adriatic_s_001680.png
# test/adriatic_sea_s_002041.png
# test/streetcar_s_000595.png
# test/beetle_s_001653.png
# test/bed_s_001040.png
# test/porcupine_s_000038.png
# test/otter_s_000002.png
# test/bear_cub_s_000067.png
# test/abel_s_000606.png
# test/lapin_s_002460.png
# test/sunflower_s_002315.png
# test/mako_shark_s_001096.png
# test/tiger_s_000032.png
# test/orchid_s_000878.png
# test/cows_s_000004.png
# test/crocodile_s_002271.png
# test/kangaroo_s_000833.png
# test/quercus_rubra_s_001039.png
# test/breakfast_table_s_000303.png
# test/river_otter_s_001064.png
# test/ribbon_worm_s_000079.png
# test/cichlid_s_000763.png
# test/rogue_elephant_s_000248.png
# test/field_s_001218.png
# test/bed_s_001121.png
# test/fishbowl_s_000477.png
# test/soda_can_s_001205.png
# test/panthera_pardus_s_001077.png
# test/cichlid_fish_s_000959.png
# test/bachelor_girl_s_000775.png
# test/pan_troglodytes_s_000101.png
# test/helminth_s_000698.png
# test/harvest_mouse_s_000137.png
# test/castor_fiber_s_000652.png
# test/panthera_leo_s_000068.png
# test/lobster_s_001310.png
# test/gecko_s_000007.png
# test/alarm_clock_s_000080.png
# test/drawbridge_s_002496.png
# test/sofa_s_000689.png
# test/castor_fiber_s_000814.png
# test/female_child_s_000199.png
# test/camel_s_001184.png
# test/cattle_s_000379.png
# test/syrian_hamster_s_000340.png
# test/cichlid_fish_s_000322.png
# test/ankylosaurus_s_001671.png
# test/couch_s_001571.png
# test/argiope_aurantia_s_000230.png
# test/tulipa_clusiana_s_000101.png
# test/colubrid_s_000741.png
# test/lift_bridge_s_002102.png
# test/telephone_set_s_001286.png
# test/maple_s_001556.png
# test/silver_maple_s_001435.png
# test/turtle_s_000817.png
# test/acer_saccharinum_s_000969.png
# test/northern_lobster_s_000033.png
# test/hedgehog_s_000032.png
# test/guided_missile_s_000603.png
# test/flounder_s_002744.png
# test/army_tank_s_000028.png
# test/elephant_s_001482.png
# test/male_child_s_000554.png
# test/camel_s_000536.png
# test/panthera_tigris_s_000282.png
# test/hamster_s_001164.png
# test/honeybee_s_000737.png
# test/male_child_s_001283.png
# test/fishbowl_s_000396.png
# test/mount_s_002065.png
# test/river_otter_s_000074.png
# test/poppy_s_001322.png
# test/pine_tree_s_000795.png
# test/giant_kangaroo_s_000381.png
# test/computer_keyboard_s_001277.png
# test/pickup_truck_s_000642.png
# test/common_opossum_s_000002.png
# test/lamp_s_002301.png
# test/girl_s_000738.png
# test/goldfish_s_002509.png
# test/lamp_s_001966.png
# test/valencia_orange_s_001719.png
# test/opossum_s_001630.png
# test/kangaroo_s_000491.png
# test/winter_flounder_s_000009.png
# test/baby_s_000101.png
# test/iguana_s_000155.png
# test/butterfly_ray_s_000875.png
# test/porcupine_s_001703.png
# test/beaver_s_000452.png
# test/castor_fiber_s_000319.png
# test/bos_taurus_s_000072.png
# test/delphinus_delphis_s_000840.png
# test/stegosaur_s_000003.png
# test/red_fox_s_000333.png
# test/serengeti_plain_s_000223.png
# test/dual_carriageway_s_000165.png
# test/pickup_s_001919.png
# test/bowhead_s_000303.png
# test/oriental_cockroach_s_000033.png
# test/racoon_s_000770.png
# test/discharge_lamp_s_001516.png
# test/chimp_s_001914.png
# test/pickup_s_001757.png
# test/fish_bowl_s_000030.png
# test/infant_s_000925.png
# test/skyscraper_s_000450.png
# test/golden_willow_s_000037.png
# test/syrian_hamster_s_001688.png
# test/dungeness_crab_s_000337.png
# test/wardrobe_s_000415.png
# test/crocodile_s_000075.png
# test/carphophis_amoenus_s_000251.png
# test/hognose_snake_s_000552.png
# test/mount_s_002461.png
# test/possum_s_000027.png
# test/adam_s_000436.png
# test/bear_cub_s_000364.png
# test/panthera_leo_s_001490.png
# test/chimp_s_002085.png
# test/computer_keyboard_s_001835.png
# test/woods_s_000022.png
# test/stingray_s_000555.png
# test/infant_s_000529.png
# test/castor_fiber_s_000472.png
# test/camel_s_002219.png
# test/wardrobe_s_001306.png
# ...
# train/striped_skunk_s_000118.png
# train/lawn_mower_s_001004.png
# train/apple_s_000626.png
# train/school_bus_s_000636.png
# train/male_child_s_001562.png
# train/mountain_rose_s_000076.png
# train/bungalow_s_000287.png
# train/adriatic_sea_s_000304.png
# train/desk_phone_s_000619.png
# train/beer_bottle_s_000117.png
# train/shark_s_000070.png
# train/boarding_house_s_001231.png
# train/sweet_pepper_s_002209.png
# train/armchair_s_000270.png
# train/right_whale_s_000486.png
# train/helix_pomatia_s_000192.png
# train/black_woman_s_000378.png
# train/slip_road_s_000379.png
# train/beetle_s_001374.png
# train/young_girl_s_000629.png
# train/hedgehog_s_001040.png
# train/dolphin_s_002583.png
# train/tin_can_s_001595.png
# train/bowl_s_000075.png
# train/lawn_mower_s_001398.png
# train/crab_s_000026.png
# train/cichlid_s_001456.png
# train/caterpillar_s_000229.png
# train/arterial_road_s_000106.png
# train/disciotis_venosa_s_000181.png
# train/alarm_clock_s_000440.png
# train/mephitis_mephitis_s_000137.png
# train/lion_s_000635.png
# train/sweet_pepper_s_001156.png
# train/chimp_s_000843.png
# train/cichlid_s_002185.png
# train/hedgehog_s_000311.png
# train/indian_elephant_s_000571.png
# train/abel_s_000408.png
# train/dozer_s_000057.png
# train/armchair_s_002052.png
# train/ornithischian_s_000049.png
# train/bigarade_s_000010.png
# train/adam_s_001381.png
# train/raccoon_s_000119.png
# train/easy_chair_s_000620.png
# train/trout_s_002565.png
# train/sofa_s_000331.png
# train/worm_snake_s_000550.png
# train/pickup_truck_s_001911.png
# train/clavier_s_000262.png
# train/dessert_plate_s_000089.png
# train/forest_s_000409.png
# train/salix_viminalis_s_000022.png
# train/electric_ray_s_000532.png
# train/access_road_s_000810.png
# train/raccoon_s_000272.png
# train/keyboard_s_000186.png
# train/pickup_truck_s_002640.png
# train/quercus_rubra_s_001318.png
# train/whiskey_bottle_s_000397.png
# train/rose_s_001114.png
# train/rainbow_trout_s_000953.png
# train/armoured_combat_vehicle_s_000661.png
# train/railroad_train_s_000041.png
# train/sea_turtle_s_001052.png
# train/cable_system_s_000041.png
# train/couch_s_001454.png
# train/dwarf_tulip_s_000186.png
# train/electric_lamp_s_000570.png
# train/boy_s_001212.png
# train/castle_s_002639.png
# train/otter_s_000675.png
# train/tiger_beetle_s_000104.png
# train/tulipa_clusiana_s_000378.png
# train/sugar_maple_s_001096.png
# train/sea_s_002203.png
# train/sea_turtle_s_000323.png
# train/tulip_s_000963.png
# train/cockroach_s_001747.png
# train/sand_dab_s_000040.png
# train/shark_s_001600.png
# train/freight_train_s_000082.png
# train/wood_s_001240.png
# train/raccoon_s_002054.png
# train/quercus_robur_s_000429.png
# train/mower_s_002112.png
# train/seal_s_002162.png
# train/clock_s_001883.png
# train/pickup_truck_s_000147.png
# train/baby_s_001845.png
# train/panthera_leo_s_001472.png
# train/power_mower_s_001081.png
# train/macoun_s_000139.png
# train/valencia_orange_s_000882.png
# train/beer_bottle_s_000270.png
# train/chimp_s_000609.png
# train/castle_s_000857.png
# train/rabbit_s_000453.png
# train/crab_s_002679.png
# train/camelus_dromedarius_s_000710.png
# train/chimp_s_002067.png
# train/water_shrew_s_000140.png
# train/built_in_bed_s_000574.png
# train/adam_s_000418.png
# train/river_otter_s_000452.png
# train/coluber_constrictor_s_000821.png
# train/research_rocket_s_000183.png
# train/salix_alba_s_000268.png
# train/beer_bottle_s_000988.png
# train/possum_s_000009.png
# train/palace_s_000640.png
# train/bear_s_001023.png
# train/plain_s_000057.png
# train/hognose_snake_s_000534.png
# train/wolf_s_001043.png
# train/dolphin_s_000729.png
# train/forest_s_002029.png
# train/bear_cub_s_000184.png
# train/masked_shrew_s_000300.png
# train/rosebush_s_000579.png
# train/squirrel_s_001969.png
# train/skyscraper_s_000036.png
# train/elephant_s_002418.png
# train/cattle_s_001864.png
# train/bear_s_000132.png
# train/beer_can_s_000386.png
# train/river_otter_s_000290.png
# train/oriental_cockroach_s_001221.png
# train/mako_shark_s_000484.png
# train/skunk_s_001111.png
# train/squirrel_s_000522.png
# train/camel_s_000095.png
# train/delphinus_delphis_s_000264.png
# train/house_s_001065.png
# train/caterpillar_s_000544.png
# train/red_delicious_s_000014.png
# train/lady_tulip_s_000306.png
# train/fox_s_000847.png
# train/chaise_s_001675.png
# train/vulpes_vulpes_s_000021.png
# train/elephant_s_000636.png
# train/couch_s_000563.png
# train/worm_s_001244.png
# train/american_lobster_s_000042.png
# train/shrew_s_000331.png
# train/bed_s_001794.png
# train/sea_turtle_s_000161.png
# train/railroad_train_s_000597.png
# train/racoon_s_000194.png
# train/delphinus_delphis_s_001317.png
# train/stingray_s_002319.png
# train/motor_mower_s_000312.png
# train/eagle_ray_s_000115.png
# train/carphophis_amoenus_s_000071.png
# train/leopard_s_002133.png
# train/castle_s_001030.png
# train/forest_s_000247.png
# train/fin_whale_s_000892.png
# train/bus_s_000499.png
# train/streetcar_s_000874.png
# train/worm_snake_s_000631.png
# train/quercus_virginiana_s_000100.png
# train/porcupine_s_001046.png
# train/red_fox_s_000711.png
# train/panthera_tigris_s_000408.png
# train/quercus_bicolor_s_000690.png
# train/skunk_s_001748.png
# train/red_fox_s_001440.png
# train/sweet_pepper_s_000661.png
# train/poppy_s_000017.png
# train/helix_pomatia_s_000039.png
# train/lobster_s_001031.png
# train/mount_s_001471.png
# train/indian_elephant_s_000094.png
# train/elephas_maximus_s_000119.png
# train/electric_lamp_s_000651.png
# train/bus_s_000024.png
# train/delphinus_delphis_s_000183.png
# train/beer_bottle_s_002133.png
# train/caterpillar_s_000463.png
# train/lobster_s_000302.png
# train/sugar_maple_s_001177.png
# train/flying_gecko_s_000195.png
# train/bos_taurus_s_000450.png
# train/lamp_s_000499.png
# train/butterfly_orchid_s_001033.png
# train/pear_s_001250.png
# train/cockroach_s_000775.png
# train/crocodylus_porosus_s_000717.png
# train/dungeness_crab_s_000076.png
# train/elephant_s_000555.png
# train/chimp_s_001419.png
# train/alarm_clock_s_001016.png
# train/computer_keyboard_s_000683.png
# train/africanized_honey_bee_s_000030.png
# train/tiger_s_001839.png
# train/valencia_orange_s_000963.png
# train/surveillance_system_s_000771.png
# train/poppy_s_002510.png
# train/quercus_borealis_s_000080.png
# train/pine_s_002288.png
# train/butterfly_s_001545.png
# train/honeybee_s_000539.png
# train/salix_purpurea_s_000057.png
# train/palace_s_001450.png
# train/goblet_s_000982.png
# train/eared_seal_s_000074.png
# train/panthera_tigris_s_000084.png
# train/cain_s_001220.png
# train/forest_s_000166.png
# train/lutra_canadensis_s_000286.png
# train/railroad_train_s_001013.png
# train/porcupine_s_001208.png
# train/streetcar_s_001765.png
# train/field_s_003036.png
# train/television_s_002831.png
# train/mower_s_001302.png
# train/baby_s_001764.png
# train/sea_s_000340.png
# train/northern_spy_s_000786.png
# train/tram_s_000336.png
# train/flounder_s_002708.png
# train/balaena_mysticetus_s_000003.png
# train/stingray_s_002076.png
# train/camel_s_000176.png
# train/soda_can_s_000035.png
# train/oriental_roach_s_000015.png
# train/white_woman_s_000626.png
# train/squirrel_s_002061.png
# train/beer_can_s_001196.png
# train/striped_skunk_s_000514.png
# train/cirrocumulus_s_000012.png
# train/apis_mellifera_s_001558.png
# train/canyon_live_oak_s_000159.png
# train/sorex_cinereus_s_000002.png
# train/grey_wolf_s_001395.png
# train/elephant_s_001446.png
# train/sea_s_002122.png
# train/orchid_s_001411.png
# train/beer_can_s_002249.png
# train/butterfly_s_001707.png
# train/crocodylus_niloticus_s_000592.png
# train/serengeti_s_000361.png
# train/field_s_001254.png
# train/spider_s_000270.png
# train/streetcar_s_002100.png
# train/common_dolphin_s_001351.png
# train/goldfish_s_000862.png
# train/little_girl_s_000023.png
# train/bowl_s_001524.png
# train/quercus_petraea_s_000016.png
# train/balaenoptera_physalus_s_000262.png
# train/oak_tree_s_001014.png
# train/cichlid_fish_s_000124.png
# train/apis_mellifera_s_000111.png
# train/syrian_hamster_s_000142.png
# train/spider_s_000315.png
# train/mushroom_s_001696.png
# train/house_mouse_s_000202.png
# train/goldfish_s_001636.png
# train/mushroom_s_000967.png
# train/possum_s_000360.png
# train/crocodylus_porosus_s_000276.png
# train/platyhelminth_s_000157.png
# train/spider_s_001044.png
# train/poppy_s_002787.png
# train/oil_palm_s_000946.png
# train/couch_s_002147.png
# train/goblet_s_001200.png
# train/beer_can_s_000188.png
# train/oriental_cockroach_s_001023.png
# train/mount_s_001354.png
# train/cain_s_000050.png
# train/sea_turtle_s_001016.png
# train/crab_s_000143.png
# train/house_mouse_s_001649.png
# train/caterpillar_s_001075.png
# train/panthera_pardus_s_000663.png
# train/mcintosh_s_000911.png
# train/adam_s_002551.png
# train/orchid_s_001132.png
# train/water_shrew_s_000104.png
# train/sunflower_s_000452.png
# train/flounder_s_000647.png
# train/clock_s_001847.png
# train/cockroach_s_000658.png
# train/man_s_001955.png
# train/marine_turtle_s_000005.png
# train/mower_s_000688.png
# train/acer_saccharinum_s_001700.png
# train/rabbit_s_001146.png
# train/lady_tulip_s_000108.png
# train/surveillance_system_s_001383.png
# train/skyscraper_s_002331.png
# train/forest_s_000049.png
# train/keyboard_s_001914.png
# train/river_otter_s_000416.png
# train/boy_s_002299.png
# train/butterfly_s_001428.png
# train/pickup_truck_s_002280.png
# train/bowl_s_000516.png
# train/bear_cub_s_000148.png
# train/television_s_002714.png
# train/tv_s_000967.png
# train/common_dolphin_s_000899.png
# train/rabbit_s_000255.png
# train/mushroom_s_001858.png
# train/bulldozer_s_000805.png
# train/salix_alba_s_000781.png
# train/guitarfish_s_001072.png
# train/tv_s_001696.png
# train/crocodylus_porosus_s_000438.png
# train/rainbow_trout_s_001808.png
# train/possum_s_000522.png
# train/castor_fiber_s_000418.png
# train/seal_s_000506.png
# train/volcano_s_000527.png
# train/gecko_s_002104.png
# train/bottle_s_001500.png
# train/pedunculate_oak_s_000093.png
# train/nile_crocodile_s_001004.png
# train/orchid_s_000959.png
# train/bell_pepper_s_000985.png
# train/table_s_000897.png
# train/leopard_s_001044.png
# train/squirrel_s_000162.png
# train/quercus_lobata_s_000204.png
# train/adriatic_s_001680.png
# train/garden_snail_s_000603.png
# train/ceratopsian_s_000502.png
# train/computer_keyboard_s_001457.png
# train/nematode_s_000964.png
# train/tulip_s_000765.png
# train/adriatic_sea_s_002041.png
# train/table_s_000503.png
# train/infant_s_000862.png
# train/house_mouse_s_001487.png
# train/pickup_s_001300.png
# train/girl_s_001809.png
# train/lift_bridge_s_000005.png
# train/eared_seal_s_000119.png
# train/streetcar_s_000595.png
# train/beetle_s_001653.png
# train/cichlid_fish_s_000007.png
# train/bed_s_001040.png
# train/porcupine_s_000038.png
# train/trout_s_001791.png
# train/yellow_delicious_s_000569.png
# train/driveway_s_000014.png
# train/mouse_s_000043.png
# train/otter_s_000002.png
# train/bear_cub_s_000067.png
# train/baby_s_001566.png
# train/abel_s_000606.png
# train/motor_mower_s_000589.png
# train/camelus_dromedarius_s_000431.png
# train/mushroom_s_001777.png
# train/rainbow_trout_s_001727.png
# train/raccoon_s_000317.png
# train/roundworm_s_000003.png
# train/spider_s_001125.png
# train/pinyon_s_000955.png
# train/lapin_s_002460.png
# train/streetcar_s_000838.png
# train/adriatic_sea_s_000896.png
# train/mount_s_000706.png
# train/breakfast_table_s_000859.png
# train/sunflower_s_002315.png
# train/caterpillar_s_000427.png
# train/mako_shark_s_001096.png
# train/tiger_s_000032.png
# train/winter_flounder_s_000027.png
# train/orchid_s_000878.png
# train/bowl_s_000273.png
# train/caterpillar_s_001156.png
# train/harvest_mouse_s_000533.png
# train/cows_s_000004.png
# train/crocodile_s_002271.png
# train/butterfly_s_001185.png
# train/squirrel_s_000081.png
# train/electric_lamp_s_000291.png
# train/hamster_s_000912.png
# train/bungalow_s_000485.png
# train/red_fox_s_001798.png
# train/wallaby_s_000202.png
# train/elephant_s_000519.png
# train/cockroach_s_000739.png
# train/manual-skunk028.png
# train/kangaroo_s_000833.png
# train/cockroach_s_000021.png
# train/skyscraper_s_002412.png
# train/pine_tree_s_000500.png
# train/kangaroo_s_002291.png
# train/decanter_s_000316.png
# train/nile_crocodile_s_000588.png
# train/giant_kangaroo_s_000480.png
# train/quercus_rubra_s_001039.png
# train/ankylosaurus_s_000384.png
# train/female_child_s_000595.png
# train/breakfast_table_s_000303.png
# train/sunflower_s_000371.png
# train/horned_dinosaur_s_000066.png
# train/balmoral_castle_s_000641.png
# train/castor_canadensis_s_000327.png
# train/bowl_s_001164.png
# train/river_otter_s_001064.png
# train/ribbon_worm_s_000079.png
# train/common_dolphin_s_000262.png
# train/soda_bottle_s_000646.png
# train/cattle_s_001909.png
# train/oriental_cockroach_s_000213.png
# train/leopard_s_000072.png
# train/stone_crab_s_001771.png
# train/cichlid_s_000763.png
# train/worm_s_002018.png
# train/armored_combat_vehicle_s_000279.png
# train/maple_s_000269.png
# train/infant_s_000943.png
# train/red_fox_s_000513.png
# train/black_woman_s_002196.png
# train/black_woman_s_000738.png
# train/volcano_s_000284.png
# train/skunk_s_002279.png
# train/rogue_elephant_s_000248.png
# train/golden_willow_s_000613.png
# train/shark_s_000430.png
# train/field_s_001218.png
# train/red_fox_s_001242.png
# train/bed_s_001121.png
# train/porcupine_s_000119.png
# train/ornithischian_s_000085.png
# train/crocodylus_niloticus_s_000556.png
# train/sunflower_s_000137.png
# train/salix_alba_s_000628.png
# train/fishbowl_s_000477.png
# train/soda_can_s_001205.png
# train/shortfin_mako_s_000165.png
# train/forest_s_001174.png
# train/camel_s_002075.png
# train/oak_tree_s_001131.png
# train/pisanosaurus_s_000021.png
# train/bell_pepper_s_000114.png
# train/stone_crab_s_000484.png
# train/panthera_pardus_s_001077.png
# train/little_girl_s_000140.png
# train/rorqual_s_000899.png
# train/rabbit_s_002271.png
# train/american_lobster_s_000240.png
# train/cichlid_fish_s_000959.png
# train/lamp_s_000778.png
# train/bachelor_girl_s_000775.png
# train/pan_troglodytes_s_000101.png
# train/electric_lamp_s_000219.png
# train/squirrel_s_000009.png
# train/baby_s_001881.png
# train/salt_flat_s_000222.png
# train/helminth_s_000698.png
# train/acer_saccharum_s_001239.png
# train/chimp_s_000645.png
# train/chimpanzee_s_002109.png
# train/beaver_s_000074.png
# train/spider_s_001440.png
# train/kangaroo_s_002930.png
# train/harvest_mouse_s_000137.png
# train/castor_fiber_s_000652.png
# train/eames_chair_s_000276.png
# train/pickup_truck_s_000183.png
# train/anjou_s_000937.png
# train/butterfly_orchid_s_000977.png
# train/seal_s_000029.png
# train/panthera_leo_s_000068.png
# train/mountain_rose_s_000913.png
# train/lapin_s_000606.png
# train/boarding_house_s_000698.png
# train/willow_tree_s_001819.png
# train/lobster_s_001310.png
# train/sweet_pepper_s_000940.png
# train/couch_s_001814.png
# train/camelus_dromedarius_s_000035.png
# train/turtle_s_000736.png
# train/gecko_s_000007.png
# train/alarm_clock_s_000080.png
# train/electric_lamp_s_000057.png
# train/king_of_beasts_s_000981.png
# train/castor_fiber_s_000490.png
# train/turtle_s_001465.png
# train/drawbridge_s_002496.png
# train/bottle_s_000132.png
# train/keyboard_s_000384.png
# train/sofa_s_000689.png
# train/mountain_rose_s_000751.png
# train/morchella_esculenta_s_000033.png
# train/beetle_s_001338.png
# train/golden_willow_s_000217.png
# train/alarm_clock_s_000798.png
# train/red_fox_s_000117.png
# train/tulip_s_001890.png
# train/beetle_s_002067.png
# train/colubrid_s_000822.png
# train/adriatic_s_003147.png
# train/bell_pepper_s_001399.png
# train/oxen_s_001032.png
# train/tiger_s_001956.png
# train/oxen_s_000303.png
# train/man_s_000031.png
# train/armored_combat_vehicle_s_000200.png
# train/castor_fiber_s_000814.png
# train/quercus_robur_s_000627.png
# train/beetle_s_000285.png
# train/baby_s_002772.png
# train/turbot_s_001555.png
# train/baleen_whale_s_001062.png
# train/phone_s_002794.png
# train/dungeness_crab_s_000193.png
# train/chimp_s_001536.png
# train/osier_s_000455.png
# train/forest_s_000283.png
# train/camel_s_000455.png
# train/eared_seal_s_000191.png
# train/panthera_pardus_s_000186.png
# train/caterpillar_s_001633.png
# train/car_train_s_000562.png
# train/mourning_cloak_s_000125.png
# train/world_trade_center_s_000108.png
# train/dolphin_s_001100.png
# train/female_child_s_000199.png
# train/chimpanzee_s_000165.png
# train/river_otter_s_000650.png
# train/camel_s_001184.png
# train/cattle_s_000379.png
# train/byroad_s_000258.png
# train/rorqual_s_000262.png
# train/sunflower_s_000218.png
# train/cirrocumulus_s_000928.png
# train/wardrobe_s_000514.png
# train/school_bus_s_000519.png
# train/syrian_hamster_s_000340.png
# train/field_s_002181.png
# train/cichlid_fish_s_000322.png
# train/snake_s_000158.png
# train/male_child_s_000716.png
# train/panthera_tigris_s_000444.png
# train/wolf_s_000987.png
# train/red_fox_s_000036.png

# %%
import requests

def extract_cifar_data(url, filename="cifar.tar.gz"):
    """A function for extracting the CIFAR-100 dataset and storing it as a gzipped file
    
    Arguments:
    url      -- the URL where the dataset is hosted
    filename -- the full path where the dataset will be written
    
    """
    
    # Todo: request the data from the data url
    # Hint: use `requests.get` method
    r = requests.get("https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz")
    with open(filename, "wb") as file_context:
        file_context.write(r.content)
    return

# %% [markdown]
# Let's test it out! Run the following cell and check whether a new file `cifar.tar.gz` is created in the file explorer.

# %%
extract_cifar_data("https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz")

# %% [markdown]
# ### 2. Transform the data into a usable shape and format
#
# Clearly, distributing the data as a gzipped archive makes sense for the hosting service! It saves on bandwidth, storage, and it's a widely-used archive format. In fact, it's so widely used that the Python community ships a utility for working with them, `tarfile`, as part of its Standard Library. Execute the following cell to decompress your extracted dataset:

# %%
import tarfile

with tarfile.open("cifar.tar.gz", "r:gz") as tar:
    tar.extractall()

# %% [markdown]
# A new folder `cifar-100-python` should be created, containing `meta`, `test`, and `train` files. These files are `pickles` and the [CIFAR homepage](https://www.cs.toronto.edu/~kriz/cifar.html) provides a simple script that can be used to load them. We've adapted the script below for you to run:

# %%
import pickle

with open("./cifar-100-python/meta", "rb") as f:
    dataset_meta = pickle.load(f, encoding='bytes')

with open("./cifar-100-python/test", "rb") as f:
    dataset_test = pickle.load(f, encoding='bytes')

with open("./cifar-100-python/train", "rb") as f:
    dataset_train = pickle.load(f, encoding='bytes')

# %%
# Feel free to explore the datasets

dataset_train.keys()
# Out:
# dict_keys([b'filenames', b'batch_label', b'fine_labels', b'coarse_labels', b'data'])

# %%
dataset_meta.keys()
# Out:
# dict_keys([b'fine_label_names', b'coarse_label_names'])

# %% [markdown]
# As documented on the homepage, `b'data'` contains rows of 3073 unsigned integers, representing three channels (red, green, and blue) for one 32x32 pixel image per row.

# %%
32*32*3
# Out:
# 3072

# %% [markdown]
# For a simple gut-check, let's transform one of our images. Each 1024 items in a row is a channel (red, green, then blue). Each 32 items in the channel are a row in the 32x32 image. Using python, we can stack these channels into a 32x32x3 array, and save it as a PNG file:

# %%
import numpy as np

# Each 1024 in a row is a channel (red, green, then blue)
row = dataset_train[b'data'][0]
red, green, blue = row[0:1024], row[1024:2048], row[2048:]

# Each 32 items in the channel are a row in the 32x32 image
red = red.reshape(32,32)
green = green.reshape(32,32)
blue = blue.reshape(32,32)

# Combine the channels into a 32x32x3 image!
combined = np.dstack((red,green,blue))

# %% [markdown]
# For a more concise version, consider the following:

# %%
# All in one:
test_image = np.dstack((
    row[0:1024].reshape(32,32),
    row[1024:2048].reshape(32,32),
    row[2048:].reshape(32,32)
))

# %%
import matplotlib.pyplot as plt
plt.imshow(test_image);

# %% [markdown]
# Looks like a cow! Let's check the label. `dataset_meta` contains label names in order, and `dataset_train` has a list of labels for each row.

# %%
dataset_train[b'fine_labels'][0]
# Out:
# 19

# %% [markdown]
# Our image has a label of `19`, so let's see what the 19th item is in the list of label names.

# %%
print(dataset_meta[b'fine_label_names'][19])
# Out:
# b'cattle'

# %% [markdown]
# Ok! 'cattle' sounds about right. By the way, using the previous two lines we can do:

# %%
n = 0
print(dataset_meta[b'fine_label_names'][dataset_train[b'fine_labels'][n]])
# Out:
# b'cattle'

# %% [markdown]
# Now we know how to check labels, is there a way that we can also check file names? `dataset_train` also contains a `b'filenames'` key. Let's see what we have here:

# %%
print(dataset_train[b'filenames'][0])
# Out:
# b'bos_taurus_s_000507.png'

# %% [markdown]
# "Taurus" is the name of a subspecies of cattle, so this looks like a pretty reasonable filename. To save an image we can also do:

# %%
plt.imsave("file.png", test_image)

# %% [markdown]
# Your new PNG file should now appear in the file explorer -- go ahead and pop it open to see!
#
# Now that you know how to reshape the images, save them as files, and capture their filenames and labels, let's just capture all the bicycles and motorcycles and save them. Scones Unlimited can use a model that tells these apart to route delivery drivers automatically.
#
# In the following cell, identify the label numbers for Bicycles and Motorcycles:

# %%
import pandas as pd

# Todo: Filter the dataset_train and dataset_meta objects to find the label numbers for Bicycle and Motorcycles
bicycles_label_number = [x for x in dataset_train[b'fine_labels'] if x == 8]
motorcycles_label_number = [i for i in dataset_train[b'fine_labels'] if i == 48]
bicycles_label_name = [k for k in dataset_meta[b'fine_label_names'] if k == b'bicycle']
motorcycles_label_number = [j for j in dataset_meta[b'fine_label_names'] if j == b'motorcycle']

# %%
dataset_train.keys()
# Out:
# dict_keys([b'filenames', b'batch_label', b'fine_labels', b'coarse_labels', b'data'])

# %% [markdown]
# Good job! We only need objects with label 8 and 48 -- this drastically simplifies our handling of the data! Below we construct a dataframe for you, and you can safely drop the rows that don't contain observations about bicycles and motorcycles. Fill in the missing lines below to drop all other rows:

# %%
#Construct the dataframe
df_train = pd.DataFrame({
    "filenames": dataset_train[b'filenames'],
    "labels": dataset_train[b'fine_labels'],
    "row": range(len(dataset_train[b'filenames']))
})

# Drop all rows from df_train where label is not 8 or 48
df_train = df_train[df_train['labels'].isin([8, 48])]

# Decode df_train.filenames so they are regular strings
df_train["filenames"] = df_train["filenames"].apply(
    lambda x: x.decode("utf-8")
)


df_test = pd.DataFrame({
    "filenames": dataset_test[b'filenames'],
    "labels": dataset_test[b'fine_labels'],
    "row": range(len(dataset_test[b'filenames']))
})

# Drop all rows from df_test where label is not 8 or 48ss
df_test = df_test[df_test['labels'].isin([8, 48])]

# Decode df_test.filenames so they are regular strings
df_test["filenames"] = df_test["filenames"].apply(
    lambda x: x.decode("utf-8")
)

# %% [markdown]
# Now that the data is filtered for just our classes, we can save all our images.

# %%
# !mkdir ./train
# !mkdir ./test
# Out:
# mkdir: cannot create directory ‘./train’: File exists
# mkdir: cannot create directory ‘./test’: File exists

# %% [markdown]
# In the previous sections we introduced you to several key snippets of code:
#
# 1. Grabbing the image data:
#
# ```python
# dataset_train[b'data'][0]
# ```
#
# 2. A simple idiom for stacking the image data into the right shape
#
# ```python
# import numpy as np
# np.dstack((
#     row[0:1024].reshape(32,32),
#     row[1024:2048].reshape(32,32),
#     row[2048:].reshape(32,32)
# ))
# ```
#
# 3. A simple `matplotlib` utility for saving images
#
# ```python
# plt.imsave(path+row['filenames'], target)
# ```
#
# Compose these together into a function that saves all the images into the `./test` and `./train` directories. Use the comments in the body of the `save_images` function below to guide your construction of the function:

# %%
df_train
# Out:
#                      filenames  labels    row
# 16           bike_s_000682.png       8     16
# 30           bike_s_000127.png       8     30
# 130         cycle_s_002598.png       8    130
# 152      minibike_s_000824.png      48    152
# 195    motorcycle_s_001856.png      48    195
# ...                        ...     ...    ...
# 49578  velocipede_s_000010.png       8  49578
# 49588  motorcycle_s_001247.png      48  49588
# 49882  motorcycle_s_000724.png      48  49882
# 49962  velocipede_s_001637.png       8  49962
# 49985  motorcycle_s_000291.png      48  49985
#
# [1000 rows x 3 columns]

# %%
dataset_train[b'data']
# Out:
# array([[255, 255, 255, ...,  10,  59,  79],
#        [255, 253, 253, ..., 253, 253, 255],
#        [250, 248, 247, ..., 194, 207, 228],
#        ...,
#        [248, 240, 236, ..., 180, 174, 205],
#        [156, 151, 151, ..., 114, 107, 126],
#        [ 31,  30,  31, ...,  72,  69,  67]], dtype=uint8)

# %%
def save_images(df, df_dict, path, row_num):
    #Grab the image data in row-major form
    img = df_dict[b'data'][row_num]
    img_filename = df['filenames'][row_num]
    
    # Consolidated stacking/reshaping from earlier
    target = np.dstack((
        img[0:1024].reshape(32, 32),
        img[1024:2048].reshape(32, 32),
        img[2048:].reshape(32, 32)
    ))
    
    # Save the image
    plt.imsave(path+img_filename, target)
    
    # Return any signal data you want for debugging
    return "data has been preprocessed successfully!"

# %%
## save ALL images using the save_images function to ./train
for i in range(len(df_train)):
    row_num = df_train['row'].iloc[i]
    save_images(df_train, dataset_train, "./train/", row_num)

# %%
## save ALL images using the save_images function to ./test
for i in range(len(df_test)):
    row_num = df_train['row'].iloc[i]
    save_images(df_train, dataset_train, "./test/", row_num)

# %% [markdown]
# ### 3. Load the data
#
# Now we can load the data into S3.
#
# Using the sagemaker SDK grab the current region, execution role, and bucket.

# %%
#### import sagemaker
import sagemaker
from sagemaker.session import Session
from sagemaker import get_execution_role

session= sagemaker.Session()
bucket= session.default_bucket()
print("Default Bucket: {}".format(bucket))

region = "us-east-1" 
print("AWS Region: {}".format(region))

role = get_execution_role()
print("RoleArn: {}".format(role))
# Out:
# Default Bucket: sagemaker-us-east-1-401485830640
# AWS Region: us-east-1
# RoleArn: arn:aws:iam::401485830640:role/service-role/AmazonSageMaker-ExecutionRole-20220311T133729

# %% [markdown]
# With this data we can easily sync your data up into S3!

# %%
import os

os.environ["DEFAULT_S3_BUCKET"] = bucket
# !aws s3 sync ./train s3://${DEFAULT_S3_BUCKET}/train/
# !aws s3 sync ./test s3://${DEFAULT_S3_BUCKET}/test/
# Out:
# upload: train/bicycle_s_000038.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000038.png
# upload: train/bicycle_s_000066.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000066.png
# upload: train/bicycle_s_000035.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000035.png
# upload: train/bicycle_s_000156.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000156.png
# upload: train/bicycle_s_000039.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000039.png
# upload: train/bicycle_s_000051.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000051.png
# upload: train/bicycle_s_000021.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000021.png
# upload: train/bicycle_s_000071.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000071.png
# upload: train/bicycle_s_000099.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000099.png
# upload: train/bicycle_s_000180.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000180.png
# upload: train/bicycle_s_000235.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000235.png
# upload: train/bicycle_s_000159.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000159.png
# upload: train/bicycle_s_000243.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000243.png
# upload: train/bicycle_s_000017.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000017.png
# upload: train/bicycle_s_000043.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000043.png
# upload: train/bicycle_s_000279.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000279.png
# upload: train/bicycle_s_000282.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000282.png
# upload: train/bicycle_s_000147.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000147.png
# upload: train/bicycle_s_000369.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000369.png
# upload: train/bicycle_s_000371.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000371.png
# upload: train/bicycle_s_000392.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000392.png
# upload: train/bicycle_s_000396.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000396.png
# upload: train/bicycle_s_000124.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000124.png
# upload: train/bicycle_s_000314.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000314.png
# upload: train/bicycle_s_000437.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000437.png
# upload: train/bicycle_s_000137.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000137.png
# upload: train/bicycle_s_000491.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000491.png
# upload: train/bicycle_s_000435.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000435.png
# upload: train/bicycle_s_000467.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000467.png
# upload: train/bicycle_s_000408.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000408.png
# upload: train/bicycle_s_000536.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000536.png
# upload: train/bicycle_s_000522.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000522.png
# upload: train/bicycle_s_000463.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000463.png
# upload: train/bicycle_s_000149.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000149.png
# upload: train/bicycle_s_000561.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000561.png
# upload: train/bicycle_s_000537.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000537.png
# upload: train/bicycle_s_000569.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000569.png
# upload: train/bicycle_s_000399.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000399.png
# upload: train/bicycle_s_000667.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000667.png
# upload: train/bicycle_s_000668.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000668.png
# upload: train/bicycle_s_000753.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000753.png
# upload: train/bicycle_s_000231.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000231.png
# upload: train/bicycle_s_000723.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000723.png
# upload: train/bicycle_s_000546.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000546.png
# upload: train/bicycle_s_000759.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000759.png
# upload: train/bicycle_s_000778.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000778.png
# upload: train/bicycle_s_000781.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000781.png
# upload: train/bicycle_s_000775.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000775.png
# upload: train/bicycle_s_000782.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000782.png
# upload: train/bicycle_s_000774.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000774.png
# upload: train/bicycle_s_000861.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000861.png
# upload: train/bicycle_s_000785.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000785.png
# upload: train/bicycle_s_000822.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000822.png
# upload: train/bicycle_s_000829.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000829.png
# upload: train/bicycle_s_000978.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000978.png
# upload: train/bicycle_s_000986.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000986.png
# upload: train/bicycle_s_000951.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000951.png
# upload: train/bicycle_s_000996.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_000996.png
# upload: train/bicycle_s_001111.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001111.png
# upload: train/bicycle_s_001002.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001002.png
# upload: train/bicycle_s_001168.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001168.png
# upload: train/bicycle_s_001174.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001174.png
# upload: train/bicycle_s_001228.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001228.png
# upload: train/bicycle_s_001203.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001203.png
# upload: train/bicycle_s_001245.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001245.png
# upload: train/bicycle_s_001247.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001247.png
# upload: train/bicycle_s_001338.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001338.png
# upload: train/bicycle_s_001348.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001348.png
# upload: train/bicycle_s_001402.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001402.png
# upload: train/bicycle_s_001205.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001205.png
# upload: train/bicycle_s_001411.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001411.png
# upload: train/bicycle_s_001569.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001569.png
# upload: train/bicycle_s_001554.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001554.png
# upload: train/bicycle_s_001388.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001388.png
# upload: train/bicycle_s_001470.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001470.png
# upload: train/bicycle_s_001452.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001452.png
# upload: train/bicycle_s_001583.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001583.png
# upload: train/bicycle_s_001409.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001409.png
# upload: train/bicycle_s_001448.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001448.png
# upload: train/bicycle_s_001642.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001642.png
# upload: train/bicycle_s_001681.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001681.png
# upload: train/bicycle_s_001693.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001693.png
# upload: train/bicycle_s_001663.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001663.png
# upload: train/bicycle_s_001688.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001688.png
# upload: train/bicycle_s_001687.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001687.png
# upload: train/bicycle_s_001748.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001748.png
# upload: train/bicycle_s_001673.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001673.png
# upload: train/bicycle_s_001679.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001679.png
# upload: train/bicycle_s_001757.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001757.png
# upload: train/bicycle_s_001814.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001814.png
# upload: train/bicycle_s_001904.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001904.png
# upload: train/bicycle_s_001928.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001928.png
# upload: train/bicycle_s_002005.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002005.png
# upload: train/bicycle_s_002012.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002012.png
# upload: train/bicycle_s_001956.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_001956.png
# upload: train/bicycle_s_002100.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002100.png
# upload: train/bicycle_s_002029.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002029.png
# upload: train/bicycle_s_002129.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002129.png
# upload: train/bicycle_s_002049.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002049.png
# upload: train/bicycle_s_002132.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002132.png
# upload: train/bicycle_s_002237.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002237.png
# upload: train/bicycle_s_002338.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002338.png
# upload: train/bicycle_s_002218.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002218.png
# upload: train/bicycle_s_002258.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002258.png
# upload: train/bicycle_s_002222.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002222.png
# upload: train/bicycle_s_002247.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002247.png
# upload: train/bicycle_s_002299.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002299.png
# upload: train/bicycle_s_002373.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002373.png
# upload: train/bicycle_s_002153.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002153.png
# upload: train/bicycle_s_002374.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002374.png
# upload: train/bicycle_s_002400.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002400.png
# upload: train/bicycle_s_002436.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002436.png
# upload: train/bicycle_s_002521.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002521.png
# upload: train/bicycle_s_002475.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002475.png
# upload: train/bicycle_s_002448.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002448.png
# upload: train/bicycle_s_002410.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002410.png
# upload: train/bicycle_s_002550.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002550.png
# upload: train/bicycle_s_002624.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002624.png
# upload: train/bicycle_s_002661.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002661.png
# upload: train/bicycle_s_002711.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002711.png
# upload: train/bicycle_s_002715.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002715.png
# upload: train/bicycle_s_002669.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002669.png
# upload: train/bicycle_s_002569.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002569.png
# upload: train/bicycle_s_002725.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002725.png
# upload: train/bicycle_s_002759.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002759.png
# upload: train/bicycle_s_002728.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002728.png
# upload: train/bike_s_000001.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000001.png
# upload: train/bicycle_s_002729.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002729.png
# upload: train/bicycle_s_002762.png to s3://sagemaker-us-east-1-401485830640/train/bicycle_s_002762.png
# upload: train/bike_s_000005.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000005.png
# upload: train/bike_s_000018.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000018.png
# upload: train/bike_s_000003.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000003.png
# upload: train/bike_s_000015.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000015.png
# upload: train/bike_s_000021.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000021.png
# upload: train/bike_s_000024.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000024.png
# upload: train/bike_s_000023.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000023.png
# upload: train/bike_s_000026.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000026.png
# upload: train/bike_s_000035.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000035.png
# upload: train/bike_s_000025.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000025.png
# upload: train/bike_s_000034.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000034.png
# upload: train/bike_s_000040.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000040.png
# upload: train/bike_s_000051.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000051.png
# upload: train/bike_s_000127.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000127.png
# upload: train/bike_s_000062.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000062.png
# upload: train/bike_s_000121.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000121.png
# upload: train/bike_s_000111.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000111.png
# upload: train/bike_s_000164.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000164.png
# upload: train/bike_s_000154.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000154.png
# upload: train/bike_s_000129.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000129.png
# upload: train/bike_s_000204.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000204.png
# upload: train/bike_s_000302.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000302.png
# upload: train/bike_s_000162.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000162.png
# upload: train/bike_s_000304.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000304.png
# upload: train/bike_s_000364.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000364.png
# upload: train/bike_s_000237.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000237.png
# upload: train/bike_s_000336.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000336.png
# upload: train/bike_s_000299.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000299.png
# upload: train/bike_s_000256.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000256.png
# upload: train/bike_s_000390.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000390.png
# upload: train/bike_s_000392.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000392.png
# upload: train/bike_s_000506.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000506.png
# upload: train/bike_s_000397.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000397.png
# upload: train/bike_s_000522.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000522.png
# upload: train/bike_s_000545.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000545.png
# upload: train/bike_s_000474.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000474.png
# upload: train/bike_s_000544.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000544.png
# upload: train/bike_s_000516.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000516.png
# upload: train/bike_s_000555.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000555.png
# upload: train/bike_s_000593.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000593.png
# upload: train/bike_s_000628.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000628.png
# upload: train/bike_s_000657.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000657.png
# upload: train/bike_s_000722.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000722.png
# upload: train/bike_s_000682.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000682.png
# upload: train/bike_s_000855.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000855.png
# upload: train/bike_s_000926.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000926.png
# upload: train/bike_s_000990.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000990.png
# upload: train/bike_s_000934.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000934.png
# upload: train/bike_s_001072.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001072.png
# upload: train/bike_s_000679.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_000679.png
# upload: train/bike_s_001093.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001093.png
# upload: train/bike_s_001078.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001078.png
# upload: train/bike_s_001200.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001200.png
# upload: train/bike_s_001131.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001131.png
# upload: train/bike_s_001260.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001260.png
# upload: train/bike_s_001226.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001226.png
# upload: train/bike_s_001116.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001116.png
# upload: train/bike_s_001113.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001113.png
# upload: train/bike_s_001027.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001027.png
# upload: train/bike_s_001320.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001320.png
# upload: train/bike_s_001414.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001414.png
# upload: train/bike_s_001380.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001380.png
# upload: train/bike_s_001375.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001375.png
# upload: train/bike_s_001418.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001418.png
# upload: train/bike_s_001572.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001572.png
# upload: train/bike_s_001592.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001592.png
# upload: train/bike_s_001462.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001462.png
# upload: train/bike_s_001519.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001519.png
# upload: train/bike_s_001415.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001415.png
# upload: train/bike_s_001517.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001517.png
# upload: train/bike_s_001613.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001613.png
# upload: train/bike_s_001683.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001683.png
# upload: train/bike_s_001761.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001761.png
# upload: train/bike_s_001739.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001739.png
# upload: train/bike_s_001847.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001847.png
# upload: train/bike_s_001767.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001767.png
# upload: train/bike_s_001877.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001877.png
# upload: train/bike_s_001827.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001827.png
# upload: train/bike_s_001876.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001876.png
# upload: train/bike_s_001839.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001839.png
# upload: train/bike_s_001679.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001679.png
# upload: train/bike_s_001928.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001928.png
# upload: train/bike_s_002033.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002033.png
# upload: train/bike_s_001915.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001915.png
# upload: train/bike_s_001980.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001980.png
# upload: train/bike_s_001945.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001945.png
# upload: train/bike_s_002024.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002024.png
# upload: train/bike_s_002042.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002042.png
# upload: train/bike_s_001897.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001897.png
# upload: train/bike_s_001882.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_001882.png
# upload: train/bike_s_002047.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002047.png
# upload: train/bike_s_002118.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002118.png
# upload: train/bike_s_002098.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002098.png
# upload: train/bike_s_002090.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002090.png
# upload: train/bike_s_002164.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002164.png
# upload: train/bike_s_002139.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002139.png
# upload: train/bike_s_002215.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002215.png
# upload: train/bike_s_002109.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002109.png
# upload: train/bike_s_002277.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002277.png
# upload: train/bike_s_002203.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002203.png
# upload: train/bike_s_002222.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002222.png
# upload: train/bike_s_002283.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002283.png
# upload: train/cycle_s_000463.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_000463.png
# upload: train/cycle_s_000583.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_000583.png
# upload: train/bike_s_002288.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002288.png
# upload: train/cycle_s_000222.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_000222.png
# upload: train/cycle_s_000639.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_000639.png
# upload: train/cycle_s_000042.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_000042.png
# upload: train/cycle_s_000318.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_000318.png
# upload: train/bike_s_002292.png to s3://sagemaker-us-east-1-401485830640/train/bike_s_002292.png
# upload: train/cycle_s_000492.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_000492.png
# upload: train/cycle_s_000871.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_000871.png
# upload: train/cycle_s_000718.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_000718.png
# upload: train/cycle_s_001309.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_001309.png
# upload: train/cycle_s_000899.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_000899.png
# upload: train/cycle_s_000666.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_000666.png
# upload: train/cycle_s_001286.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_001286.png
# upload: train/cycle_s_001412.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_001412.png
# upload: train/cycle_s_001439.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_001439.png
# upload: train/cycle_s_001472.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_001472.png
# upload: train/cycle_s_001374.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_001374.png
# upload: train/cycle_s_001735.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_001735.png
# upload: train/cycle_s_001474.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_001474.png
# upload: train/cycle_s_001745.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_001745.png
# upload: train/cycle_s_001477.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_001477.png
# upload: train/cycle_s_001413.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_001413.png
# upload: train/cycle_s_002015.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002015.png
# upload: train/cycle_s_001640.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_001640.png
# upload: train/cycle_s_002053.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002053.png
# upload: train/cycle_s_001976.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_001976.png
# upload: train/cycle_s_001875.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_001875.png
# upload: train/cycle_s_002092.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002092.png
# upload: train/cycle_s_002168.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002168.png
# upload: train/cycle_s_002090.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002090.png
# upload: train/cycle_s_002093.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002093.png
# upload: train/cycle_s_002178.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002178.png
# upload: train/cycle_s_002503.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002503.png
# upload: train/cycle_s_002399.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002399.png
# upload: train/cycle_s_002703.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002703.png
# upload: train/cycle_s_002638.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002638.png
# upload: train/cycle_s_002651.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002651.png
# upload: train/cycle_s_002666.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002666.png
# upload: train/cycle_s_002659.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002659.png
# upload: train/cycle_s_002746.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002746.png
# upload: train/cycle_s_002844.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002844.png
# upload: train/cycle_s_002598.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002598.png
# upload: train/cycle_s_002904.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002904.png
# upload: train/cycle_s_002882.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002882.png
# upload: train/cycle_s_003006.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_003006.png
# upload: train/cycle_s_002779.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002779.png
# upload: train/cycle_s_003008.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_003008.png
# upload: train/cycle_s_003026.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_003026.png
# upload: train/cycle_s_003043.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_003043.png
# upload: train/cycle_s_002978.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_002978.png
# upload: train/cycle_s_003147.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_003147.png
# upload: train/cycle_s_003122.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_003122.png
# upload: train/dirt_bike_s_000003.png to s3://sagemaker-us-east-1-401485830640/train/dirt_bike_s_000003.png
# upload: train/dirt_bike_s_000005.png to s3://sagemaker-us-east-1-401485830640/train/dirt_bike_s_000005.png
# upload: train/cycle_s_003162.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_003162.png
# upload: train/cycle_s_003148.png to s3://sagemaker-us-east-1-401485830640/train/cycle_s_003148.png
# upload: train/dirt_bike_s_000017.png to s3://sagemaker-us-east-1-401485830640/train/dirt_bike_s_000017.png
# upload: train/dirt_bike_s_000059.png to s3://sagemaker-us-east-1-401485830640/train/dirt_bike_s_000059.png
# upload: train/dirt_bike_s_000030.png to s3://sagemaker-us-east-1-401485830640/train/dirt_bike_s_000030.png
# upload: train/dirt_bike_s_000119.png to s3://sagemaker-us-east-1-401485830640/train/dirt_bike_s_000119.png
# upload: train/dirt_bike_s_000124.png to s3://sagemaker-us-east-1-401485830640/train/dirt_bike_s_000124.png
# upload: train/minibike_s_000010.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000010.png
# upload: train/minibike_s_000035.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000035.png
# upload: train/minibike_s_000020.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000020.png
# upload: train/minibike_s_000064.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000064.png
# upload: train/minibike_s_000022.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000022.png
# upload: train/minibike_s_000099.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000099.png
# upload: train/dirt_bike_s_000134.png to s3://sagemaker-us-east-1-401485830640/train/dirt_bike_s_000134.png
# upload: train/minibike_s_000108.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000108.png
# upload: train/minibike_s_000011.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000011.png
# upload: train/minibike_s_000102.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000102.png
# upload: train/minibike_s_000116.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000116.png
# upload: train/minibike_s_000110.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000110.png
# upload: train/minibike_s_000117.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000117.png
# upload: train/minibike_s_000036.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000036.png
# upload: train/minibike_s_000121.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000121.png
# upload: train/minibike_s_000146.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000146.png
# upload: train/minibike_s_000203.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000203.png
# upload: train/minibike_s_000130.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000130.png
# upload: train/minibike_s_000165.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000165.png
# upload: train/minibike_s_000149.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000149.png
# upload: train/minibike_s_000127.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000127.png
# upload: train/minibike_s_000218.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000218.png
# upload: train/minibike_s_000244.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000244.png
# upload: train/minibike_s_000340.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000340.png
# upload: train/minibike_s_000293.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000293.png
# upload: train/minibike_s_000314.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000314.png
# upload: train/minibike_s_000350.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000350.png
# upload: train/minibike_s_000362.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000362.png
# upload: train/minibike_s_000335.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000335.png
# upload: train/minibike_s_000324.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000324.png
# upload: train/minibike_s_000392.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000392.png
# upload: train/minibike_s_000402.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000402.png
# upload: train/minibike_s_000401.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000401.png
# upload: train/minibike_s_000427.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000427.png
# upload: train/minibike_s_000408.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000408.png
# upload: train/minibike_s_000435.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000435.png
# upload: train/minibike_s_000434.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000434.png
# upload: train/minibike_s_000429.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000429.png
# upload: train/minibike_s_000409.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000409.png
# upload: train/minibike_s_000451.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000451.png
# upload: train/minibike_s_000491.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000491.png
# upload: train/minibike_s_000485.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000485.png
# upload: train/minibike_s_000459.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000459.png
# upload: train/minibike_s_000519.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000519.png
# upload: train/minibike_s_000522.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000522.png
# upload: train/minibike_s_000511.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000511.png
# upload: train/minibike_s_000498.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000498.png
# upload: train/minibike_s_000507.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000507.png
# upload: train/minibike_s_000518.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000518.png
# upload: train/minibike_s_000520.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000520.png
# upload: train/minibike_s_000526.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000526.png
# upload: train/minibike_s_000565.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000565.png
# upload: train/minibike_s_000527.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000527.png
# upload: train/minibike_s_000570.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000570.png
# upload: train/minibike_s_000568.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000568.png
# upload: train/minibike_s_000566.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000566.png
# upload: train/minibike_s_000613.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000613.png
# upload: train/minibike_s_000567.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000567.png
# upload: train/minibike_s_000571.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000571.png
# upload: train/minibike_s_000569.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000569.png
# upload: train/minibike_s_000698.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000698.png
# upload: train/minibike_s_000654.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000654.png
# upload: train/minibike_s_000701.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000701.png
# upload: train/minibike_s_000652.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000652.png
# upload: train/minibike_s_000690.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000690.png
# upload: train/minibike_s_000741.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000741.png
# upload: train/minibike_s_000709.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000709.png
# upload: train/minibike_s_000738.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000738.png
# upload: train/minibike_s_000800.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000800.png
# upload: train/minibike_s_000743.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000743.png
# upload: train/minibike_s_000802.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000802.png
# upload: train/minibike_s_000830.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000830.png
# upload: train/minibike_s_000831.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000831.png
# upload: train/minibike_s_000813.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000813.png
# upload: train/minibike_s_000824.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000824.png
# upload: train/minibike_s_000820.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000820.png
# upload: train/minibike_s_000885.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000885.png
# upload: train/minibike_s_000855.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000855.png
# upload: train/minibike_s_000886.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000886.png
# upload: train/minibike_s_000914.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000914.png
# upload: train/minibike_s_001016.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001016.png
# upload: train/minibike_s_001079.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001079.png
# upload: train/minibike_s_000906.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000906.png
# upload: train/minibike_s_000968.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000968.png
# upload: train/minibike_s_001072.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001072.png
# upload: train/minibike_s_001017.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001017.png
# upload: train/minibike_s_001157.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001157.png
# upload: train/minibike_s_001168.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001168.png
# upload: train/minibike_s_001094.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001094.png
# upload: train/minibike_s_000967.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_000967.png
# upload: train/minibike_s_001179.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001179.png
# upload: train/minibike_s_001185.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001185.png
# upload: train/minibike_s_001177.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001177.png
# upload: train/minibike_s_001191.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001191.png
# upload: train/minibike_s_001261.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001261.png
# upload: train/minibike_s_001169.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001169.png
# upload: train/minibike_s_001270.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001270.png
# upload: train/minibike_s_001193.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001193.png
# upload: train/minibike_s_001249.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001249.png
# upload: train/minibike_s_001250.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001250.png
# upload: train/minibike_s_001294.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001294.png
# upload: train/minibike_s_001275.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001275.png
# upload: train/minibike_s_001366.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001366.png
# upload: train/minibike_s_001458.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001458.png
# upload: train/minibike_s_001344.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001344.png
# upload: train/minibike_s_001279.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001279.png
# upload: train/minibike_s_001345.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001345.png
# upload: train/minibike_s_001348.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001348.png
# upload: train/minibike_s_001450.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001450.png
# upload: train/minibike_s_001417.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001417.png
# upload: train/minibike_s_001479.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001479.png
# upload: train/minibike_s_001498.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001498.png
# upload: train/minibike_s_001539.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001539.png
# upload: train/minibike_s_001512.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001512.png
# upload: train/minibike_s_001506.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001506.png
# upload: train/minibike_s_001511.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001511.png
# upload: train/minibike_s_001491.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001491.png
# upload: train/minibike_s_001540.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001540.png
# upload: train/minibike_s_001496.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001496.png
# upload: train/minibike_s_001546.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001546.png
# upload: train/minibike_s_001565.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001565.png
# upload: train/minibike_s_001575.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001575.png
# upload: train/minibike_s_001558.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001558.png
# upload: train/minibike_s_001597.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001597.png
# upload: train/minibike_s_001573.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001573.png
# upload: train/minibike_s_001638.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001638.png
# upload: train/minibike_s_001639.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001639.png
# upload: train/minibike_s_001653.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001653.png
# upload: train/minibike_s_001689.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001689.png
# upload: train/minibike_s_001631.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001631.png
# upload: train/minibike_s_001701.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001701.png
# upload: train/minibike_s_001691.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001691.png
# upload: train/minibike_s_001734.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001734.png
# upload: train/minibike_s_001747.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001747.png
# upload: train/minibike_s_001731.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001731.png
# upload: train/minibike_s_001771.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001771.png
# upload: train/minibike_s_001827.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001827.png
# upload: train/minibike_s_001789.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001789.png
# upload: train/minibike_s_001767.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001767.png
# upload: train/minibike_s_001829.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001829.png
# upload: train/minibike_s_001836.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001836.png
# upload: train/minibike_s_001838.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001838.png
# upload: train/minibike_s_001865.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001865.png
# upload: train/minibike_s_001870.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001870.png
# upload: train/minibike_s_001863.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001863.png
# upload: train/minibike_s_001880.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001880.png
# upload: train/minibike_s_001873.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001873.png
# upload: train/minibike_s_001917.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001917.png
# upload: train/minibike_s_001885.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001885.png
# upload: train/minibike_s_001921.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001921.png
# upload: train/minibike_s_001996.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001996.png
# upload: train/minibike_s_001972.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001972.png
# upload: train/minibike_s_002009.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002009.png
# upload: train/minibike_s_001944.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001944.png
# upload: train/minibike_s_002030.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002030.png
# upload: train/minibike_s_001969.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001969.png
# upload: train/minibike_s_002046.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002046.png
# upload: train/minibike_s_002038.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002038.png
# upload: train/minibike_s_001881.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_001881.png
# upload: train/minibike_s_002048.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002048.png
# upload: train/minibike_s_002130.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002130.png
# upload: train/minibike_s_002115.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002115.png
# upload: train/minibike_s_002146.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002146.png
# upload: train/minibike_s_002124.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002124.png
# upload: train/minibike_s_002163.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002163.png
# upload: train/minibike_s_002176.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002176.png
# upload: train/minibike_s_002182.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002182.png
# upload: train/minibike_s_002196.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002196.png
# upload: train/minibike_s_002194.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002194.png
# upload: train/minibike_s_002084.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002084.png
# upload: train/minibike_s_002186.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002186.png
# upload: train/minibike_s_002218.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002218.png
# upload: train/minibike_s_002137.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002137.png
# upload: train/moped_s_000004.png to s3://sagemaker-us-east-1-401485830640/train/moped_s_000004.png
# upload: train/minibike_s_002198.png to s3://sagemaker-us-east-1-401485830640/train/minibike_s_002198.png
# upload: train/moped_s_000009.png to s3://sagemaker-us-east-1-401485830640/train/moped_s_000009.png
# ...
# upload: test/bike_s_001679.png to s3://sagemaker-us-east-1-401485830640/test/bike_s_001679.png
# upload: test/bike_s_001320.png to s3://sagemaker-us-east-1-401485830640/test/bike_s_001320.png
# upload: test/cycle_s_000899.png to s3://sagemaker-us-east-1-401485830640/test/cycle_s_000899.png
# upload: test/cycle_s_001474.png to s3://sagemaker-us-east-1-401485830640/test/cycle_s_001474.png
# upload: test/cycle_s_001640.png to s3://sagemaker-us-east-1-401485830640/test/cycle_s_001640.png
# upload: test/cycle_s_002053.png to s3://sagemaker-us-east-1-401485830640/test/cycle_s_002053.png
# upload: test/cycle_s_001745.png to s3://sagemaker-us-east-1-401485830640/test/cycle_s_001745.png
# upload: test/cycle_s_002651.png to s3://sagemaker-us-east-1-401485830640/test/cycle_s_002651.png
# upload: test/cycle_s_002638.png to s3://sagemaker-us-east-1-401485830640/test/cycle_s_002638.png
# upload: test/dirt_bike_s_000017.png to s3://sagemaker-us-east-1-401485830640/test/dirt_bike_s_000017.png
# upload: test/cycle_s_002978.png to s3://sagemaker-us-east-1-401485830640/test/cycle_s_002978.png
# upload: test/cycle_s_002598.png to s3://sagemaker-us-east-1-401485830640/test/cycle_s_002598.png
# upload: test/cycle_s_002703.png to s3://sagemaker-us-east-1-401485830640/test/cycle_s_002703.png
# upload: test/dirt_bike_s_000030.png to s3://sagemaker-us-east-1-401485830640/test/dirt_bike_s_000030.png
# upload: test/dirt_bike_s_000124.png to s3://sagemaker-us-east-1-401485830640/test/dirt_bike_s_000124.png
# upload: test/minibike_s_000110.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000110.png
# upload: test/minibike_s_000117.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000117.png
# upload: test/minibike_s_000165.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000165.png
# upload: test/minibike_s_000146.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000146.png
# upload: test/minibike_s_000362.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000362.png
# upload: test/minibike_s_000350.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000350.png
# upload: test/minibike_s_000324.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000324.png
# upload: test/minibike_s_000402.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000402.png
# upload: test/minibike_s_000518.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000518.png
# upload: test/minibike_s_000526.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000526.png
# upload: test/minibike_s_000571.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000571.png
# upload: test/minibike_s_000654.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000654.png
# upload: test/minibike_s_000652.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000652.png
# upload: test/minibike_s_000743.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000743.png
# upload: test/minibike_s_000885.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000885.png
# upload: test/minibike_s_000451.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000451.png
# upload: test/minibike_s_001185.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_001185.png
# upload: test/minibike_s_000824.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000824.png
# upload: test/minibike_s_001017.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_001017.png
# upload: test/minibike_s_001279.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_001279.png
# upload: test/minibike_s_001631.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_001631.png
# upload: test/minibike_s_001573.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_001573.png
# upload: test/minibike_s_001511.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_001511.png
# upload: test/minibike_s_000565.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_000565.png
# upload: test/minibike_s_001177.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_001177.png
# upload: test/minibike_s_001827.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_001827.png
# upload: test/minibike_s_001546.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_001546.png
# upload: test/minibike_s_001653.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_001653.png
# upload: test/minibike_s_001969.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_001969.png
# upload: test/minibike_s_002009.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_002009.png
# upload: test/minibike_s_002198.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_002198.png
# upload: test/minibike_s_001689.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_001689.png
# upload: test/minibike_s_001972.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_001972.png
# upload: test/moped_s_000035.png to s3://sagemaker-us-east-1-401485830640/test/moped_s_000035.png
# upload: test/moped_s_000009.png to s3://sagemaker-us-east-1-401485830640/test/moped_s_000009.png
# upload: test/moped_s_000169.png to s3://sagemaker-us-east-1-401485830640/test/moped_s_000169.png
# upload: test/motorbike_s_000058.png to s3://sagemaker-us-east-1-401485830640/test/motorbike_s_000058.png
# upload: test/minibike_s_001863.png to s3://sagemaker-us-east-1-401485830640/test/minibike_s_001863.png
# upload: test/motorbike_s_000117.png to s3://sagemaker-us-east-1-401485830640/test/motorbike_s_000117.png
# upload: test/motorbike_s_000141.png to s3://sagemaker-us-east-1-401485830640/test/motorbike_s_000141.png
# upload: test/motorbike_s_000124.png to s3://sagemaker-us-east-1-401485830640/test/motorbike_s_000124.png
# upload: test/motorbike_s_000346.png to s3://sagemaker-us-east-1-401485830640/test/motorbike_s_000346.png
# upload: test/motorbike_s_000172.png to s3://sagemaker-us-east-1-401485830640/test/motorbike_s_000172.png
# upload: test/motorbike_s_000254.png to s3://sagemaker-us-east-1-401485830640/test/motorbike_s_000254.png
# upload: test/motorbike_s_000541.png to s3://sagemaker-us-east-1-401485830640/test/motorbike_s_000541.png
# upload: test/moped_s_000030.png to s3://sagemaker-us-east-1-401485830640/test/moped_s_000030.png
# upload: test/motorcycle_s_000001.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000001.png
# upload: test/motorbike_s_000221.png to s3://sagemaker-us-east-1-401485830640/test/motorbike_s_000221.png
# upload: test/motorcycle_s_000074.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000074.png
# upload: test/motorcycle_s_000025.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000025.png
# upload: test/motorcycle_s_000220.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000220.png
# upload: test/motorcycle_s_000245.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000245.png
# upload: test/motorcycle_s_000300.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000300.png
# upload: test/motorcycle_s_000256.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000256.png
# upload: test/motorcycle_s_000167.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000167.png
# upload: test/motorcycle_s_000418.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000418.png
# upload: test/motorcycle_s_000508.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000508.png
# upload: test/motorcycle_s_000605.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000605.png
# upload: test/motorcycle_s_000713.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000713.png
# upload: test/motorcycle_s_000629.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000629.png
# upload: test/motorcycle_s_000787.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000787.png
# upload: test/motorcycle_s_000454.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000454.png
# upload: test/motorcycle_s_000790.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000790.png
# upload: test/motorcycle_s_000070.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000070.png
# upload: test/motorcycle_s_000923.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000923.png
# upload: test/motorcycle_s_000447.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000447.png
# upload: test/motorcycle_s_000776.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000776.png
# upload: test/motorcycle_s_000978.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000978.png
# upload: test/motorcycle_s_001119.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001119.png
# upload: test/motorcycle_s_000991.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_000991.png
# upload: test/motorcycle_s_001180.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001180.png
# upload: test/motorcycle_s_001363.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001363.png
# upload: test/motorcycle_s_001303.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001303.png
# upload: test/motorcycle_s_001368.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001368.png
# upload: test/motorcycle_s_001064.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001064.png
# upload: test/motorcycle_s_001176.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001176.png
# upload: test/motorcycle_s_001287.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001287.png
# upload: test/motorcycle_s_001580.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001580.png
# upload: test/motorcycle_s_001370.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001370.png
# upload: test/motorcycle_s_001610.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001610.png
# upload: test/motorcycle_s_001453.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001453.png
# upload: test/motorcycle_s_001792.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001792.png
# upload: test/motorcycle_s_002105.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_002105.png
# upload: test/motorcycle_s_002143.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_002143.png
# upload: test/motorcycle_s_001973.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001973.png
# upload: test/motorcycle_s_001856.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001856.png
# upload: test/motorcycle_s_001693.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001693.png
# upload: test/motorcycle_s_001905.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_001905.png
# upload: test/ordinary_bicycle_s_000036.png to s3://sagemaker-us-east-1-401485830640/test/ordinary_bicycle_s_000036.png
# upload: test/ordinary_bicycle_s_000023.png to s3://sagemaker-us-east-1-401485830640/test/ordinary_bicycle_s_000023.png
# upload: test/motorcycle_s_002225.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_002225.png
# upload: test/ordinary_bicycle_s_000060.png to s3://sagemaker-us-east-1-401485830640/test/ordinary_bicycle_s_000060.png
# upload: test/ordinary_bicycle_s_000161.png to s3://sagemaker-us-east-1-401485830640/test/ordinary_bicycle_s_000161.png
# upload: test/ordinary_bicycle_s_000100.png to s3://sagemaker-us-east-1-401485830640/test/ordinary_bicycle_s_000100.png
# upload: test/motorcycle_s_002030.png to s3://sagemaker-us-east-1-401485830640/test/motorcycle_s_002030.png
# upload: test/ordinary_bicycle_s_000216.png to s3://sagemaker-us-east-1-401485830640/test/ordinary_bicycle_s_000216.png
# upload: test/ordinary_bicycle_s_000107.png to s3://sagemaker-us-east-1-401485830640/test/ordinary_bicycle_s_000107.png
# upload: test/ordinary_bicycle_s_000201.png to s3://sagemaker-us-east-1-401485830640/test/ordinary_bicycle_s_000201.png
# upload: test/ordinary_bicycle_s_000432.png to s3://sagemaker-us-east-1-401485830640/test/ordinary_bicycle_s_000432.png
# upload: test/ordinary_bicycle_s_000355.png to s3://sagemaker-us-east-1-401485830640/test/ordinary_bicycle_s_000355.png
# upload: test/ordinary_bicycle_s_000451.png to s3://sagemaker-us-east-1-401485830640/test/ordinary_bicycle_s_000451.png
# upload: test/ordinary_bicycle_s_000297.png to s3://sagemaker-us-east-1-401485830640/test/ordinary_bicycle_s_000297.png
# upload: test/safety_bicycle_s_000359.png to s3://sagemaker-us-east-1-401485830640/test/safety_bicycle_s_000359.png
# upload: test/safety_bicycle_s_000655.png to s3://sagemaker-us-east-1-401485830640/test/safety_bicycle_s_000655.png
# upload: test/safety_bicycle_s_001049.png to s3://sagemaker-us-east-1-401485830640/test/safety_bicycle_s_001049.png
# upload: test/safety_bicycle_s_000255.png to s3://sagemaker-us-east-1-401485830640/test/safety_bicycle_s_000255.png
# upload: test/safety_bicycle_s_001202.png to s3://sagemaker-us-east-1-401485830640/test/safety_bicycle_s_001202.png
# upload: test/safety_bicycle_s_000427.png to s3://sagemaker-us-east-1-401485830640/test/safety_bicycle_s_000427.png
# upload: test/safety_bicycle_s_001253.png to s3://sagemaker-us-east-1-401485830640/test/safety_bicycle_s_001253.png
# upload: test/safety_bicycle_s_001381.png to s3://sagemaker-us-east-1-401485830640/test/safety_bicycle_s_001381.png
# upload: test/safety_bicycle_s_001320.png to s3://sagemaker-us-east-1-401485830640/test/safety_bicycle_s_001320.png
# upload: test/safety_bicycle_s_001240.png to s3://sagemaker-us-east-1-401485830640/test/safety_bicycle_s_001240.png
# upload: test/safety_bike_s_000058.png to s3://sagemaker-us-east-1-401485830640/test/safety_bike_s_000058.png
# upload: test/safety_bike_s_000100.png to s3://sagemaker-us-east-1-401485830640/test/safety_bike_s_000100.png
# upload: test/safety_bike_s_000567.png to s3://sagemaker-us-east-1-401485830640/test/safety_bike_s_000567.png
# upload: test/safety_bike_s_000311.png to s3://sagemaker-us-east-1-401485830640/test/safety_bike_s_000311.png
# upload: test/safety_bicycle_s_001570.png to s3://sagemaker-us-east-1-401485830640/test/safety_bicycle_s_001570.png
# upload: test/safety_bike_s_000921.png to s3://sagemaker-us-east-1-401485830640/test/safety_bike_s_000921.png
# upload: test/safety_bike_s_000482.png to s3://sagemaker-us-east-1-401485830640/test/safety_bike_s_000482.png
# upload: test/safety_bike_s_000830.png to s3://sagemaker-us-east-1-401485830640/test/safety_bike_s_000830.png
# upload: test/safety_bike_s_001552.png to s3://sagemaker-us-east-1-401485830640/test/safety_bike_s_001552.png
# upload: test/velocipede_s_000139.png to s3://sagemaker-us-east-1-401485830640/test/velocipede_s_000139.png
# upload: test/safety_bike_s_000989.png to s3://sagemaker-us-east-1-401485830640/test/safety_bike_s_000989.png
# upload: test/safety_bike_s_001608.png to s3://sagemaker-us-east-1-401485830640/test/safety_bike_s_001608.png
# upload: test/velocipede_s_000586.png to s3://sagemaker-us-east-1-401485830640/test/velocipede_s_000586.png
# upload: test/velocipede_s_000282.png to s3://sagemaker-us-east-1-401485830640/test/velocipede_s_000282.png
# upload: test/velocipede_s_001056.png to s3://sagemaker-us-east-1-401485830640/test/velocipede_s_001056.png
# upload: test/velocipede_s_001142.png to s3://sagemaker-us-east-1-401485830640/test/velocipede_s_001142.png
# upload: test/velocipede_s_001883.png to s3://sagemaker-us-east-1-401485830640/test/velocipede_s_001883.png
# upload: test/safety_bike_s_000934.png to s3://sagemaker-us-east-1-401485830640/test/safety_bike_s_000934.png
# upload: test/velocipede_s_000949.png to s3://sagemaker-us-east-1-401485830640/test/velocipede_s_000949.png
# upload: test/velocipede_s_001585.png to s3://sagemaker-us-east-1-401485830640/test/velocipede_s_001585.png
# upload: test/velocipede_s_001338.png to s3://sagemaker-us-east-1-401485830640/test/velocipede_s_001338.png
# upload: test/velocipede_s_001958.png to s3://sagemaker-us-east-1-401485830640/test/velocipede_s_001958.png
# upload: test/velocipede_s_000825.png to s3://sagemaker-us-east-1-401485830640/test/velocipede_s_000825.png

# %% [markdown]
# And that's it! You can check the bucket and verify that the items were uploaded.
#
# ## Model Training
#
# For Image Classification, Sagemaker [also expects metadata](https://docs.aws.amazon.com/sagemaker/latest/dg/image-classification.html) e.g. in the form of TSV files with labels and filepaths. We can generate these using our Pandas DataFrames from earlier:

# %%
def to_metadata_file(df, prefix):
    df["s3_path"] = df["filenames"]
    df["labels"] = df["labels"].apply(lambda x: 0 if x==8 else 1)
    return df[["row", "labels", "s3_path"]].to_csv(
        f"{prefix}.lst", sep="\t", index=False, header=False
    )
    
to_metadata_file(df_train.copy(), "train")
to_metadata_file(df_test.copy(), "test")

# %% [markdown]
# We can also upload our manifest files:

# %%
import boto3

# Upload files
boto3.Session().resource('s3').Bucket(
    bucket).Object('train.lst').upload_file('./train.lst')
boto3.Session().resource('s3').Bucket(
    bucket).Object('test.lst').upload_file('./test.lst')

# %% [markdown]
# Using the `bucket` and `region` info we can get the latest prebuilt container to run our training job, and define an output location on our s3 bucket for the model. Use the `image_uris` function from the SageMaker SDK to retrieve the latest `image-classification` image below:

# %%
# Use the image_uris function to retrieve the latest 'image-classification' image 
algo_image = sagemaker.image_uris.retrieve(framework='image-classification', region='us-east-1', version='lastest')
s3_output_location = f"s3://{bucket}/models/image_model"
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: lastest.

# %% [markdown]
# We're ready to create an estimator! Create an estimator `img_classifier_model` that uses one instance of `ml.p2.xlarge`. Ensure that y ou use the output location we defined above - we'll be referring to that later!

# %%
session = sagemaker.Session()
img_classifier_model=sagemaker.estimator.Estimator(
    algo_image,
    instance_count=1,
    instance_type='ml.p2.xlarge',    
    output_path=s3_output_location,
    role=role,
    sagemaker_Session=session,
    base_job_name='scones-unlimited-training-job'
)

# %% [markdown]
# We can also set a few key hyperparameters and define the inputs for our model:

# %%
img_classifier_model.set_hyperparameters(
    image_shape="3,32,32", # TODO: Fill in
    num_classes=2, # TODO: Fill in
    num_training_samples=1000# TODO: fill in
)

# %% [markdown]
# The `image-classification` image uses four input channels with very specific input parameters. For convenience, we've provided them below:

# %%
from sagemaker.debugger import Rule, rule_configs
from sagemaker.session import TrainingInput
model_inputs = {
        "train": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/train/",
            content_type="application/x-image"
        ),
        "validation": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/test/",
            content_type="application/x-image"
        ),
        "train_lst": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/train.lst",
            content_type="application/x-image"
        ),
        "validation_lst": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/test.lst",
            content_type="application/x-image"
        )
}

# %% [markdown]
# Great, now we can train the model using the model_inputs. In the cell below, call the `fit` method on our model,:

# %%
## TODO: train your model
img_classifier_model.fit(model_inputs, logs=True)
# Out:
# 2022-04-25 15:06:31 Starting - Starting the training job...
# 2022-04-25 15:06:59 Starting - Preparing the instances for trainingProfilerReport-1650899191: InProgress
# ............
# 2022-04-25 15:08:56 Downloading - Downloading input data...
# 2022-04-25 15:09:16 Training - Downloading the training image.........
# 2022-04-25 15:10:56 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# [04/25/2022 15:10:57 INFO 140314650466112] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/image_classification/default-input.json: {'use_pretrained_model': 0, 'num_layers': 152, 'epochs': 30, 'learning_rate': 0.1, 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': 32, 'image_shape': '3,224,224', 'precision_dtype': 'float32'}
# [04/25/2022 15:10:57 INFO 140314650466112] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'image_shape': '3,32,32', 'num_classes': '2', 'num_training_samples': '1000'}
# [04/25/2022 15:10:57 INFO 140314650466112] Final configuration: {'use_pretrained_model': 0, 'num_layers': 152, 'epochs': 30, 'learning_rate': 0.1, 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': 32, 'image_shape': '3,32,32', 'precision_dtype': 'float32', 'num_classes': '2', 'num_training_samples': '1000'}
# [04/25/2022 15:10:57 INFO 140314650466112] Searching for .lst files in /opt/ml/input/data/train_lst.
# [04/25/2022 15:10:57 INFO 140314650466112] Creating record files for train.lst
# [04/25/2022 15:10:57 INFO 140314650466112] Done creating record files...
# [04/25/2022 15:10:57 INFO 140314650466112] Searching for .lst files in /opt/ml/input/data/validation_lst.
# [04/25/2022 15:10:57 INFO 140314650466112] Creating record files for test.lst
# clean up /tmp/tmpbpfluxm4/test.rec, /tmp/tmpbpfluxm4/test.idx and /opt/ml/input/data/validation
# [04/25/2022 15:10:57 ERROR 140314650466112] Customer Error: imread read blank (None) image for file: /opt/ml/input/data/validation/safety_bike_s_000390.png
# [04/25/2022 15:10:57 ERROR 140314650466112 integration.py:628] Customer Error: imread read blank (None) image for file: /opt/ml/input/data/validation/safety_bike_s_000390.png
# Traceback (most recent call last):
#   File "/opt/amazon/lib/python3.7/site-packages/image_classification/start.py", line 245, in main
#     args = args_factory.get_args(training_args)
#   File "/opt/amazon/lib/python3.7/site-packages/image_classification/args_factory.py", line 632, in get_args
#     algorithm_args = self.get_algorithm_args(training_config_filename, training_args)
#   File "/opt/amazon/lib/python3.7/site-packages/image_classification/args_factory.py", line 388, in get_algorithm_args
#     training_args["use_weighted_loss"],
#   File "/opt/amazon/lib/python3.7/site-packages/image_classification/args_factory.py", line 249, in get_input_files
#     val_lst_path, "validation_lst", val_image_dir, resize, multi_label
#   File "/opt/amazon/lib/python3.7/site-packages/image_classification/args_factory.py", line 106, in get_lst_files
#     rec_file_name, rec_file_path = self.create_rec_files(lst_name, lst_path, image_dir, resize, multi_label)
#   File "/opt/amazon/lib/python3.7/site-packages/image_classification/args_factory.py", line 49, in create_rec_files
#     raise e
#   File "/opt/amazon/lib/python3.7/site-packages/image_classification/args_factory.py", line 45, in create_rec_files
#     im2rec.build_rec_files(resize, lst_dir, image_dir, multi_label, temp_file_path)
#   File "/opt/amazon/lib/python3.7/site-packages/image_classification/im2rec.py", line 213, in build_rec_files
#     raise e
#   File "/opt/amazon/lib/python3.7/site-packages/image_classification/im2rec.py", line 208, in build_rec_files
#     image_encode(args, i, item, q_out)
#   File "/opt/amazon/lib/python3.7/site-packages/image_classification/im2rec.py", line 73, in image_encode
#     raise exceptions.CustomerError(f"imread read blank (None) image for file: {fullpath}")
# ai_algorithms_sdk.base.exceptions.CustomerError: imread read blank (None) image for file: /opt/ml/input/data/validation/safety_bike_s_000390.png
#
# 2022-04-25 15:11:19 Uploading - Uploading generated training model
# 2022-04-25 15:11:19 Failed - Training job failed
# ProfilerReport-1650899191: Stopping
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-35-cc65bcc76109> in <module>
#       1 ## TODO: train your model
# ----> 2 img_classifier_model.fit(model_inputs, logs=True)
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     953         self.jobs.append(self.latest_training_job)
#     954         if wait:
# --> 955             self.latest_training_job.wait(logs=logs)
#     956
#     957     def _compilation_job_name(self):
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1952         # If logs are requested, call logs_for_jobs.
#    1953         if logs != "None":
# -> 1954             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1955         else:
#    1956             self.sagemaker_session.wait_for_job(self.job_name)
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3790
#    3791         if wait:
# -> 3792             self._check_job_status(job_name, description, "TrainingJobStatus")
#    3793             if dot:
#    3794                 print()
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    3331                 message=message,
#    3332                 allowed_statuses=["Completed", "Stopped"],
# -> 3333                 actual_status=status,
#    3334             )
#    3335
#
# UnexpectedStatusException: Error for Training job scones-unlimited-training-job-2022-04-25-15-06-31-348: Failed. Reason: ClientError: imread read blank (None) image for file: /opt/ml/input/data/validation/safety_bike_s_000390.png, exit code: 2

# %% [markdown]
# If all goes well, you'll end up with a model topping out above `.8` validation accuracy. With only 1000 training samples in the CIFAR dataset, that's pretty good. We could definitely pursue data augmentation & gathering more samples to help us improve further, but for now let's proceed to deploy our model.
#
# ### Getting ready to deploy
#
# To begin with, let's configure Model Monitor to track our deployment. We'll define a `DataCaptureConfig` below:

# %%
from sagemaker.model_monitor import DataCaptureConfig

data_capture_config = DataCaptureConfig(
    ## TODO: Set config options
    destination_s3_uri=f"s3://{bucket}/data_capture"
)

# %% [markdown]
# Note the `destination_s3_uri` parameter: At the end of the project, we can explore the `data_capture` directory in S3 to find crucial data about the inputs and outputs Model Monitor has observed on our model endpoint over time.
#
# With that done, deploy your model on a single `ml.m5.xlarge` instance with the data capture config attached:

# %%
deployment = img_classifier_model.deploy(
    ## TODO: fill in deployment options
    data_capture_config=data_capture_config
    )

endpoint = deployment.endpoint_name
print(endpoint)

# %% [markdown]
# Note the endpoint name for later as well.
#
# Next, instantiate a Predictor:

# %%
predictor = ## TODO: fill in

# %% [markdown]
# In the code snippet below we are going to prepare one of your saved images for prediction. Use the predictor to process the `payload`.

# %%
from sagemaker.serializers import IdentitySerializer
import base64

predictor.serializer = IdentitySerializer("image/png")
with open("./test/bicycle_s_001789.png", "rb") as f:
    payload = f.read()

    
inference = ## TODO: Process the payload with your predictor

# %% [markdown]
# Your `inference` object is an array of two values, the predicted probability value for each of your classes (bicycle and motorcycle respectively.) So, for example, a value of `b'[0.91, 0.09]'` indicates the probability of being a bike is 91% and being a motorcycle is 9%.

# %%
print(inference)

# %% [markdown]
# ### Draft Lambdas and Step Function Workflow
#
# Your operations team uses Step Functions to orchestrate serverless workflows. One of the nice things about Step Functions is that [workflows can call other workflows](https://docs.aws.amazon.com/step-functions/latest/dg/connect-stepfunctions.html), so the team can easily plug your workflow into the broader production architecture for Scones Unlimited.
#
# In this next stage you're going to write and deploy three Lambda functions, and then use the Step Functions visual editor to chain them together! Our functions are going to work with a simple data object:
#
# ```python
# {
#     "inferences": [], # Output of predictor.predict
#     "s3_key": "", # Source data S3 key
#     "s3_bucket": "", # Source data S3 bucket
#     "image_data": ""  # base64 encoded string containing the image data
# }
# ```
#
# A good test object that you can use for Lambda tests and Step Function executions, throughout the next section, might look like this:
#
# ```python
# {
#   "image_data": "",
#   "s3_bucket": MY_BUCKET_NAME, # Fill in with your bucket
#   "s3_key": "test/bicycle_s_000513.png"
# }
# ```
#
# Using these fields, your functions can read and write the necessary data to execute your workflow. Let's start with the first function. Your first Lambda function will copy an object from S3, base64 encode it, and then return it to the step function as `image_data` in an event.
#
# Go to the Lambda dashboard and create a new Lambda function with a descriptive name like "serializeImageData" and select thr 'Python 3.8' runtime. Add the same permissions as the SageMaker role you created earlier. (Reminder: you do this in the Configuration tab under "Permissions"). Once you're ready, use the starter code below to craft your Lambda handler:
#
# ```python
# import json
# import boto3
# import base64
#
# s3 = boto3.client('s3')
#
# def lambda_handler(event, context):
#     """A function to serialize target data from S3"""
#
#     # Get the s3 address from the Step Function event input
#     key = ## TODO: fill in
#     bucket = ## TODO: fill in
#
#     # Download the data from s3 to /tmp/image.png
#     ## TODO: fill in
#
#     # We read the data from a file
#     with open("/tmp/image.png", "rb") as f:
#         image_data = base64.b64encode(f.read())
#
#     # Pass the data back to the Step Function
#     print("Event:", event.keys())
#     return {
#         'statusCode': 200,
#         'body': {
#             "image_data": image_data,
#             "s3_bucket": bucket,
#             "s3_key": key,
#             "inferences": []
#         }
#     }
# ```
#
# The next function is responsible for the classification part - we're going to take the image output from the previous function, decode it, and then pass inferences back to the the Step Function.
#
# Because this Lambda will have runtime dependencies (i.e. the SageMaker SDK) you'll need to package them in your function. *Key reading:* https://docs.aws.amazon.com/lambda/latest/dg/python-package-create.html#python-package-create-with-dependency
#
# Create a new Lambda function with the same rights and a descriptive name, then fill in the starter code below for your classifier Lambda.
#
# ```python
# import json
# import sagemaker
# import base64
# from sagemaker.serializers import IdentitySerializer
#
# # Fill this in with the name of your deployed model
# ENDPOINT = ## TODO: fill in
#
# def lambda_handler(event, context):
#
#     # Decode the image data
#     image = base64.b64decode(## TODO: fill in)
#
#     # Instantiate a Predictor
#     predictor = ## TODO: fill in
#
#     # For this model the IdentitySerializer needs to be "image/png"
#     predictor.serializer = IdentitySerializer("image/png")
#
#     # Make a prediction:
#     inferences = ## TODO: fill in
#
#     # We return the data back to the Step Function
#     event["inferences"] = inferences.decode('utf-8')
#     return {
#         'statusCode': 200,
#         'body': json.dumps(event)
#     }
# ```
#
# Finally, we need to filter low-confidence inferences. Define a threshold between 1.00 and 0.000 for your model: what is reasonble for you? If the model predicts at `.70` for it's highest confidence label, do we want to pass that inference along to downstream systems? Make one last Lambda function and tee up the same permissions:
#
# ```python
# import json
#
#
# THRESHOLD = .93
#
#
# def lambda_handler(event, context):
#
#     # Grab the inferences from the event
#     inferences = ## TODO: fill in
#
#     # Check if any values in our inferences are above THRESHOLD
#     meets_threshold = ## TODO: fill in
#
#     # If our threshold is met, pass our data back out of the
#     # Step Function, else, end the Step Function with an error
#     if meets_threshold:
#         pass
#     else:
#         raise("THRESHOLD_CONFIDENCE_NOT_MET")
#
#     return {
#         'statusCode': 200,
#         'body': json.dumps(event)
#     }
# ```
# Once you have tested the lambda functions, save the code for each lambda function in a python script called 'lambda.py'.
#
# With your lambdas in place, you can use the Step Functions visual editor to construct a workflow that chains them together. In the Step Functions console you'll have the option to author a Standard step function *Visually*.
#
# When the visual editor opens, you'll have many options to add transitions in your workflow. We're going to keep it simple and have just one: to invoke Lambda functions. Add three of them chained together. For each one, you'll be able to select the Lambda functions you just created in the proper order, filter inputs and outputs, and give them descriptive names.
#
# Make sure that you:
#
# 1. Are properly filtering the inputs and outputs of your invokations (e.g. `$.body`)
# 2. Take care to remove the error handling from the last function - it's supposed to "fail loudly" for your operations colleagues!
#
# Take a screenshot of your working step function in action and export the step function as JSON for your submission package.

# %% [markdown]
# Great! Now you can use the files in `./test` as test files for our workflow. Depending on our threshold, our workflow should reliably pass predictions about images from `./test` on to downstream systems, while erroring out for inferences below our confidence threshold!
#
# ### Testing and Evaluation
#
# Do several step function invokations using data from the `./test` folder. This process should give you confidence that the workflow both *succeeds* AND *fails* as expected. In addition, SageMaker Model Monitor will generate recordings of your data and inferences which we can visualize.
#
# Here's a function that can help you generate test inputs for your invokations:

# %%
import random
import boto3
import json


def generate_test_case():
    # Setup s3 in boto3
    s3 = boto3.resource('s3')
    
    # Randomly pick from sfn or test folders in our bucket
    objects = s3.Bucket(bucket).objects.filter("test")
    
    # Grab any random object key from that folder!
    obj = random.choice([x.key for x in objects])
    
    return json.dumps({
        "image_data": "",
        "s3_bucket": bucket,
        "s3_key": obj
    })
generate_test_case()

# %% [markdown]
# In the Step Function dashboard for your new function, you can create new executions and copy in the generated test cases. Do several executions so that you can generate data you can evaluate and visualize.
#
# Once you've done several executions, let's visualize the record of our inferences. Pull in the JSONLines data from your inferences like so:

# %%
from sagemaker.s3 import S3Downloader

# In S3 your data will be saved to a datetime-aware path
# Find a path related to a datetime you're interested in
data_path = ## TODO: fill in the path to your captured data

S3Downloader.download(data_path, "captured_data")

# Feel free to repeat this multiple times and pull in more data

# %% [markdown]
# The data are in JSONLines format, where multiple valid JSON objects are stacked on top of eachother in a single `jsonl` file. We'll import an open-source library, `jsonlines` that was purpose built for parsing this format.

# %%
# !pip install jsonlines
import jsonlines

# %% [markdown]
# Now we can extract the data from each of the source files:

# %%
import os

# List the file names we downloaded
file_handles = os.listdir("./captured_data")

# Dump all the data into an array
json_data = []
for jsonl in file_handles:
    with jsonlines.open(f"./captured_data/{jsonl}") as f:
        json_data.append(f.read())

# %% [markdown]
# The data should now be a list of dictionaries, with significant nesting. We'll give you an example of some code that grabs data out of the objects and visualizes it:

# %%
# Define how we'll get our data
def simple_getter(obj):
    inferences = obj["captureData"]["endpointOutput"]["data"]
    timestamp = obj["eventMetadata"]["inferenceTime"]
    return json.loads(inferences), timestamp

simple_getter(json_data[0])

# %% [markdown]
# Finally, here's an example of a visualization you can build with this data. In this last part, you will take some time and build your own - the captured data has the input images, the resulting inferences, and the timestamps.

# %%
# Populate the data for the x and y axis
x = []
y = []
for obj in json_data:
    inference, timestamp = simple_getter(obj)
    
    y.append(max(inference))
    x.append(timestamp)

# Todo: here is an visualization example, take some time to build another visual that helps monitor the result
# Plot the data
plt.scatter(x, y, c=['r' if k<.94 else 'b' for k in y ])
plt.axhline(y=0.94, color='g', linestyle='--')
plt.ylim(bottom=.88)

# Add labels
plt.ylabel("Confidence")
plt.suptitle("Observed Recent Inferences", size=14)
plt.title("Pictured with confidence threshold for production use", size=10)

# Give it some pizzaz!
plt.style.use("Solarize_Light2")
plt.gcf().autofmt_xdate()

# %% [markdown]
# ### Todo: build your own visualization

# %% [markdown]
# ### Congratulations!
#
# You've reached the end of the project. In this project you created an event-drivent ML workflow that can be incorporated into the Scones Unlimited production architecture. You used the SageMaker Estimator API to deploy your SageMaker Model and Endpoint, and you used AWS Lambda and Step Functions to orchestrate your ML workflow. Using SageMaker Model Monitor, you instrumented and observed your Endpoint, and at the end of the project you built a visualization to help stakeholders understand the performance of the Endpoint over time. If you're up for it, you can even go further with these stretch goals:
#
# * Extend your workflow to incorporate more classes: the CIFAR dataset includes other vehicles that Scones Unlimited can identify with this model.
# * Modify your event driven workflow: can you rewrite your Lambda functions so that the workflow can process multiple image inputs in parallel? Can the Step Function "fan out" to accomodate this new workflow?
# * Consider the test data generator we provided for you. Can we use it to create a "dummy data" generator, to simulate a continuous stream of input data? Or a big paralell load of data?
# * What if we want to get notified every time our step function errors out? Can we use the Step Functions visual editor in conjunction with a service like SNS to accomplish this? Try it out!
